# %% [markdown]
# # Видобуток та збагачення структурованих даних

# %% [markdown]
# ### ТЕОРЕТИЧНА ЧАСТИНА ТА ПРИКЛАДИ

# %% [markdown]
# Для роботи з структурованими табличними даними, які розміщені в реляційній БД [SQLite](https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=&cad=rja&uact=8&ved=2ahUKEwiUyMOv1orvAhWDK3cKHac9DyMQFjAAegQIBxAD&url=https%3A%2F%2Fru.wikipedia.org%2Fwiki%2FSQLite&usg=AOvVaw1s-RMK2VC2tXyDZxZXDYDo) в Python передбачена стандартна бібліотека [sqlite3](https://docs.python.org/3/library/sqlite3.html)

# %%
# підключення бібліотеки
import sqlite3

# %% [markdown]
# #### ПРИКЛАД ВИЛУЧЕННЯ ДАНИХ З БД
# Створити БД SQLite з ім'ям `FIT-3m`, та імпорувати в неї таблицю, що містить журнал групи `jornal`

# %%
# створюємо з'єднання з БД
conn = sqlite3.connect("FIT-3m.db")

# %% [markdown]
# [імпорт csv файла в sqlite через CLI](https://www.sqlitetutorial.net/sqlite-import-csv/)

# %%
# створюємо об'єкт `cursor`, що відповідає за реалізацію операцій з таблицями БД
cur = conn.cursor()

# %%
print(type(cur), end='\n\n')
print(dir(cur))
# Out:
# <class 'sqlite3.Cursor'>
#
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'arraysize', 'close', 'connection', 'description', 'execute', 'executemany', 'executescript', 'fetchall', 'fetchmany', 'fetchone', 'lastrowid', 'row_factory', 'rowcount', 'setinputsizes', 'setoutputsize']

# %% [markdown]
# ##### виведемо ВСІ записи таблиці `jornal`

# %%
# створимо інстанс для операції `SELECT`
students_cur = cur.execute("SELECT * FROM jornal")

# будуємо список записів за допомогою метода `fetchall()`
students_list = students_cur.fetchall()

_ = [print(x) for x in students_list]
# Out:
# ('Адаменко', 'Назар', 'N.Adamenko')
# ('Акішев', 'Володимир', 'v.akishev')
# ('Акунішніков', 'Єгор', 'Y.Akunishnikov')
# ('Артюх', 'Федір', 'f.artyukh')
# ('Барабаш', 'Нікіта', None)
# ('Бойчас', 'Валентин', 'v.boychas')
# ('Будюка', 'Тимур', 'T.Budyuka')
# ('Горб', 'Богдан', 'B.Horb')
# ('Дьяков', 'Денис', 'D.Dyakov')
# ('Іванченко', 'Сергій', None)
# ('Колесник', 'Дмитро', 'D.Kolesnyk')
# ('Мозговенко', 'Денис', 'd.mozhovenko')
# ('Муха', 'Кирило', None)
# ('Назаренко', 'Катерина', None)
# ('Очеретний', 'Олексій', 'O.Ocheretnyy')
# ('Поліщук', 'Аліна', None)
# ('Поліщук', 'Владислав', None)
# ('Полюхович', 'Аліна', 'A.Polyukhovych')
# ('Старовойтов', 'Олександр', 'O.Starovoytov')
# ('Тарнавський', 'Ростислав', None)
# ('Тимошенко', 'Євгеній', 'Y.Tymoshenko')
# ('Харчевка', 'Іван', 'I.Kharchevka')

# %% [markdown]
# #### ПРИКЛАД ЗБАГАЧЕННЯ ДАНИХ З ЗОВНІШНЬОГО ДЖЕРЕЛА
#
# Додати до списка студентів їх оцінки за вступне тестування, які розташовані в csv файлі `test_result.csv`

# %% [markdown]
# імпортуємо `test_result.csv` в робочу БД як таблицю `test`
#
# [імпорт csv файла в sqlite через CLI](https://www.sqlitetutorial.net/sqlite-import-csv/)

# %% [markdown]
# ##### Cтворимо нову таблицю, яка буде містити вміст таблиці `jornal` та поле оцінок з таблиці `test`

# %%
# створимо вираз на побудову пустої таблиці `jornal_test` з відповідними полями
sql_stmt = "CREATE TABLE IF NOT EXISTS jornal_test \
              (Surname TEXT,         \
               Name TEXT,            \
               Email TEXT,           \
               Test_result INT);"

# виконаемо запит на створення таблиці
cur.execute(sql_stmt)

# перевіримо стан виконання операції - виведемо список таблиць
tables_list = cur.execute("SELECT name FROM sqlite_master WHERE type = 'table';")
tables_list.fetchall()
# Out:
# [('jornal',), ('test',), ('jornal_test',)]

# %%
# створимо запит на об'єднання таблиць 'jornal' та 'test' по прізвищу студента
sql_stmt = "SELECT jornal.*, test.Test_result FROM  \
            jornal LEFT JOIN test ON jornal.Surname = test.Surname "
# test.\"Оцінка/100\" | test.\"Ім\'я\"

# для перевірки виконаємо і виведемо результати запиту
cur.execute(sql_stmt).fetchall()
# Out:
# [('Адаменко', 'Назар', 'N.Adamenko', '82'),
#  ('Акішев', 'Володимир', 'v.akishev', '76'),
#  ('Акунішніков', 'Єгор', 'Y.Akunishnikov', '79'),
#  ('Артюх', 'Федір', 'f.artyukh', '89'),
#  ('Барабаш', 'Нікіта', None, '81'),
#  ('Бойчас', 'Валентин', 'v.boychas', '75'),
#  ('Будюка', 'Тимур', 'T.Budyuka', '67'),
#  ('Горб', 'Богдан', 'B.Horb', '83'),
#  ('Дьяков', 'Денис', 'D.Dyakov', '91'),
#  ('Іванченко', 'Сергій', None, '73'),
#  ('Колесник', 'Дмитро', 'D.Kolesnyk', '68'),
#  ('Мозговенко', 'Денис', 'd.mozhovenko', '74'),
#  ('Муха', 'Кирило', None, '78'),
#  ('Назаренко', 'Катерина', None, '87'),
#  ('Очеретний', 'Олексій', 'O.Ocheretnyy', '94'),
#  ('Поліщук', 'Аліна', None, '65'),
#  ('Поліщук', 'Аліна', None, '71'),
#  ('Поліщук', 'Владислав', None, '65'),
#  ('Поліщук', 'Владислав', None, '71'),
#  ('Полюхович', 'Аліна', 'A.Polyukhovych', '88'),
#  ('Старовойтов', 'Олександр', 'O.Starovoytov', '92'),
#  ('Тарнавський', 'Ростислав', None, '77'),
#  ('Тимошенко', 'Євгеній', 'Y.Tymoshenko', '84'),
#  ('Харчевка', 'Іван', 'I.Kharchevka', '90')]

# %%
# заповнимо пусту таблицю результатми  запиту на злиття
_ = cur.execute("INSERT INTO jornal_test " + sql_stmt)

# %%
# збережемо вміст нової таблиці в список
jornal_test_list = cur.execute("SELECT * FROM jornal_test").fetchall()

_ = [print(x) for x in jornal_test_list]
# Out:
# ('Адаменко', 'Назар', 'N.Adamenko', 82)
# ('Акішев', 'Володимир', 'v.akishev', 76)
# ('Акунішніков', 'Єгор', 'Y.Akunishnikov', 79)
# ('Артюх', 'Федір', 'f.artyukh', 89)
# ('Барабаш', 'Нікіта', None, 81)
# ('Бойчас', 'Валентин', 'v.boychas', 75)
# ('Будюка', 'Тимур', 'T.Budyuka', 67)
# ('Горб', 'Богдан', 'B.Horb', 83)
# ('Дьяков', 'Денис', 'D.Dyakov', 91)
# ('Іванченко', 'Сергій', None, 73)
# ('Колесник', 'Дмитро', 'D.Kolesnyk', 68)
# ('Мозговенко', 'Денис', 'd.mozhovenko', 74)
# ('Муха', 'Кирило', None, 78)
# ('Назаренко', 'Катерина', None, 87)
# ('Очеретний', 'Олексій', 'O.Ocheretnyy', 94)
# ('Поліщук', 'Аліна', None, 65)
# ('Поліщук', 'Аліна', None, 71)
# ('Поліщук', 'Владислав', None, 65)
# ('Поліщук', 'Владислав', None, 71)
# ('Полюхович', 'Аліна', 'A.Polyukhovych', 88)
# ('Старовойтов', 'Олександр', 'O.Starovoytov', 92)
# ('Тарнавський', 'Ростислав', None, 77)
# ('Тимошенко', 'Євгеній', 'Y.Tymoshenko', 84)
# ('Харчевка', 'Іван', 'I.Kharchevka', 90)

# %%
# завершимо всі транзакції
conn.commit()

# закріємо з'єднання
conn.close()

# %% [markdown]
# #### ПРИКЛАД  ДЕСКРИПТИВНОГО АНАЛІЗУ ДАНИХ
#
# Провести [попередній аналіз](https://ru.wikipedia.org/wiki/Описательная_статистика) отриманих даних з ціллю виявленя відхилень, помилок та інших непридатних даних.

# %% [markdown]
# Сведемо результати аналізу в таблицю, яка має наступний вигляд:
#
# №| Показчик | Значення
# :--:|:-------|-------:
# 1| кількість спостережень | xx
# 2| кількість пустих значень | xx
# 4| середній бал|  xx.x
# 5| максимальний бал | xx
# 6| мінімальний бал  | xx
# 7| стандартне відхилення | xx.x
# 8| розмах вариації  | xx

# %%
# підключимо бібліотеку 'numpy' і дамо їй аліас 'np'
import numpy as np

# %% [markdown]
# ознайомитись з призначенням, можливостями та основним функціями [бібліотеки numpy](https://numpy.org)

# %%
# перетворимо список студетів в numpay матрицю
jornal_test_arr = np.array(jornal_test_list)

# %%
print(type (jornal_test_arr), jornal_test_arr.shape)
# Out:
# <class 'numpy.ndarray'> (24, 4)

# %%
# створимо масив с результатами тестів 
test_result = np.delete(jornal_test_arr, [0,1,2], 1)

# %%
# Значення 'None' - не є числом, то заміним його на 0
test_result[test_result == None] = 0

# %%
# будуємо словник з вихідними розрахунками
result_dict = {
    "кількість спостережень"   : len(test_result),
    "кількість пустих значень" : len(test_result) - np.count_nonzero(test_result),
    "середній бал"             : round(np.mean(test_result),1),
    "максимальний бал"         : np.max(test_result),
    "мінімальний бал"          : np.min(test_result[np.nonzero(test_result)]),
    "стандартне відхилення"    : round(np.std(test_result),1),
    "розмах вариації"          : np.max(test_result) - np.min(test_result[np.nonzero(test_result)]) 
    }

# %%
result_dict
# Out:
# {'кількість спостережень': 24,
#  'кількість пустих значень': 0,
#  'середній бал': 79.2,
#  'максимальний бал': 94,
#  'мінімальний бал': 65,
#  'стандартне відхилення': 8.7,
#  'розмах вариації': 29}

# %%
# вивести шапку
print(
"""
=======================================
№  : ПОКАЗЧИК               : ЗНАЧЕННЯ     
=======================================
"""      
      )

# вивести результати аналізу датасета
i = 1
for key, value in result_dict.items():
    print (f'{i:<3} {key:<25}  {value}')
    i += 1
# Out:
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     24
# 2   кількість пустих значень   0
# 3   середній бал               79.2
# 4   максимальний бал           94
# 5   мінімальний бал            65
# 6   стандартне відхилення      8.7
# 7   розмах вариації            29

# %% [markdown]
# ### ІНДИВІДУАЛЬНЕ ЗАВДАННЯ

# %% [markdown]
# Користуючись результатами, що отримані в [Лабораторній роботі № 3](https://shkliarskiy.moodlecloud.com/mod/page/view.php?id=1193) виконати процедури видобутку, збагачення та попереднього аналізу даних.
#
# __Постановка__: В 3-й лабораторній роботі отримано показчик, що характеризує окрему властивість квартири (ціна, метраж та ін.).
# Необхідно:
# 1. Відобразити цей показчик на адресу квартири, яка знаходиться в файлі `street_name.csv`, тобто побудувати новий файл `street_flat_propery.csv` якій містить 2 колонки: _<назва вулиці> <ваш показчик>_
# 2. На основі цьго файлу зробити відповідну таблицю в _SQLite_ та збагатити цю дані в цій таблиці назвою району де розташована квартира (дані по районах додаються)
# 3. Провести попередній аналіз отриманих даних - вивести первинні статистики показчика по районах (_середне_ , _мінімальне_ , _максимальне_ і т.д. - див. приклад вище)

# %%
lst = [] # пустий список для зберігання значень 7-го показника (до внесення змін)
pls = [] # пустий список для зберігання оброблених значень (після внесення змін)

# відкриття вихідного CSV-файлу (для читання) для отримання даних
with open("./aprts_data_raw.csv", 'r', encoding='utf-8') as f1:
        
    # циклічний запис значень 7-го показника (адреса будинку)
    lst = [ln.split(',')[7].strip() for ln in list(f1)]
    
    # циклічна обробка рядка лишаючи лише один пробіл між словами
    for ls in lst:

        while True:
    
            ls = ls.replace('   ', ' ').strip() if ls.find('   ') > -1 else ls.replace('  ', ' ').strip()
            
            if ls.find('  ') > -1:
                continue
            else:
                break
        
        pls += [ls]
    
    print(f"(1): {pls[:10]}\n| len: {len(pls)}", end='\n\n') # len: 796
        
    lst = []
    
    # циклічна обробка показника адреси лишаючи лише назву
    for pl in pls:
            
        if pl.find("ул. ") > -1 or pl.find(" ул.") > -1:

            lst += [pl.replace('ул.', '').strip()]

        elif pl.find("просп. ") > -1 or pl.find(" просп.") > -1:

            lst += [pl.replace('просп.', '').strip()]

        elif pl.find("бульв. ") > -1 or pl.find(" бульв.") > -1:

            lst += [pl.replace('бульв.', '').strip()]

        elif pl.find("наб. ") > -1 or pl.find(" наб.") > -1:

            lst += [pl.replace('наб.', '').strip()]

        elif pl.find("пер. ") > -1 or pl.find(" пер.") > -1:

            lst += [pl.replace('пер.', '').strip()]            

        elif pl.find("туп. ") > -1 or pl.find(" туп.") > -1:

            lst += [pl.replace('туп.', '').strip()]            

        elif pl.find("ш. ") > -1 or pl.find(" ш.") > -1:

            lst += [pl.replace('ш.', '').strip()]

        elif pl.find("спуск ") > -1 or pl.find(" спуск") > -1:

            lst += [pl.replace('спуск', '').strip()]

        elif pl.find("пл. ") > -1 or pl.find(" пл.") > -1:

            lst += [pl.replace('пл.', '').strip()]            

        else:
            
            lst += [pl.strip()]

    print(f"(2): {lst[:10]}\n| len: {len(lst)}", end='\n\n')
        
    for q, ls in enumerate(lst[:10]):
        print(f"[{str(q+1).rjust(3)}]: {ls}")
    
# створення/відкриття нового TXT-файлу (для запису) для запису отриманих даних після приведення формату
with open("./street_name_(2).csv", 'w+', encoding='utf-8') as f2:
        
    # циклічний запис у текстовий файл значень 7-го показника (після обробки)
    for l in lst:
        f2.write(str(l) + "\n") # кожен запис з нового рядка
# Out:
# (1): ['ул. Малиновского', 'ул. Семьи Сосниных', 'просп. Лобановского (Краснозвездный)', 'ул. Руставели', 'ул. Ломоносова', 'ул. Институтская', 'ул. Антоновича (Горького)', 'Днепровская наб.', 'ул. Предславинская', 'ул. Коперника']
# | len: 796
#
# (2): ['Малиновского', 'Семьи Сосниных', 'Лобановского (Краснозвездный)', 'Руставели', 'Ломоносова', 'Институтская', 'Антоновича (Горького)', 'Днепровская', 'Предславинская', 'Коперника']
# | len: 796
#
# [  1]: Малиновского
# [  2]: Семьи Сосниных
# [  3]: Лобановского (Краснозвездный)
# [  4]: Руставели
# [  5]: Ломоносова
# [  6]: Институтская
# [  7]: Антоновича (Горького)
# [  8]: Днепровская
# [  9]: Предславинская
# [ 10]: Коперника

# %%
# Злиття файлу з показчиком та файлу з назвами вулиць в новий файл

YOUR_FILE = 'aprt_total_area.txt' # підставте ваш файл з Лаб №3...
with open(YOUR_FILE, encoding='utf-8') as f1, \
     open('street_name_ukr_(2).csv', encoding='utf-8') as f2, \
     open('street_flat_propery.csv', 'w', encoding='utf-8') as f3:
    
    f3.write(f'total_area,street\n')
    
    for x, y in zip(f1, f2):
        line = f'{x[:-1].strip()},{y[:-1].strip()}\n'
        print(line)
        f3.write(line)
# Out:
# 73.0,Малиновського
#
# 110.27,Сім'ї Сосніних
#
# 100.0,Лобановського (Червонозоряний)
#
# 58.0,Руставелі
#
# 79.0,Ломоносова
#
# 138.7,Інститутська
#
# 201.4,Антоновича (Горького)
#
# 87.0,Дніпровська
#
# 40.0,Предславинська
#
# 51.0,Коперника
#
# 48.0,Драгомирова
#
# 85.0,Драгомирова
#
# 76.0,Ревуцького
#
# 56.0,Пожарського
#
# 38.0,Гмирі
#
# 70.0,Приозерна
#
# 103.0,Коперника
#
# 56.44,Стеценка
#
# 69.0,Каштанова
#
# 47.39,Правди
#
# 50.0,Трускавецька
#
# 64.0,Наумова
#
# 96.0,Лобановського (Червонозоряний)
#
# 46.0,Салютна
#
# 44.0,Василенка
#
# 100.0,Палладіна
#
# 240.0,Міт. А. Шептицького (Анатолія Луначарського)
#
# 72.1,Балтійський
#
# 75.0,Дніпровська
#
# 78.0,Станіславського
#
# 126.0,Драгомирова
#
# 93.0,Правди
#
# 63.0,Максимовича (Онуфрія Трутенко)
#
# 44.0,ЖК PARKLAND
#
# 67.92,Причальна
#
# 52.0,Перемоги (Брест-Литовський)
#
# 99.0,Богданівська
#
# 96.0,Тверський
#
# 65.0,Набережно-Хрещатицька
#
# 50.0,Липківського (Урицького)
#
# 76.0,Правди
#
# 45.3,Дніпровська
#
# 99.0,Тютюнника (Анрі Барбюса)
#
# 74.7,3-кімнатна квартира 74
#
# 59.0,Правди
#
# 73.0,Закревського
#
# 62.0,Тверський
#
# 76.0,Туполєва
#
# 76.0,Глибочицька
#
# 210.0,Січових Стрільців (Артема)
#
# 33.0,Вишгородська
#
# 66.8,Бойчука (Кіквідзе)
#
# 62.0,Предславинська
#
# 102.1,Вадима Гетьмана
#
# 110.0,Драгоманова
#
# 51.0,Ніжинська
#
# 44.0,Кучера
#
# 91.0,Голосіївський (40-річчя Жовтня)
#
# 28.0,Іллєнко (Мельникова)
#
# 56.0,Бойчука (Кіквідзе)
#
# 67.3,Половецька
#
# 100.0,Володимирська
#
# 82.0,Гончара
#
# 122.0,Антоновича (Горького)
#
# 45.0,Метрологічна
#
# 75.0,Калнишевського (Михайло Майорова)
#
# 34.0,Зарічна
#
# 46.0,Тичини
#
# 100.0,Саперно-Слобідська
#
# 99.0,Комарова
#
# 75.0,Б. Житомирська
#
# 62.0,Каховська
#
# 76.0,Глибочицька
#
# 210.0,Січових Стрільців (Артема)
#
# 33.0,Вишгородська
#
# 66.8,Бойчука (Кіквідзе)
#
# 62.0,Предславинська
#
# 102.1,Вадима Гетьмана
#
# 110.0,Драгоманова
#
# 51.0,Ніжинська
#
# 44.0,Кучера
#
# 91.0,Голосіївський (40-річчя Жовтня)
#
# 28.0,Іллєнко (Мельникова)
#
# 56.0,Бойчука (Кіквідзе)
#
# 67.3,Половецька
#
# 100.0,Володимирська
#
# 82.0,Гончара
#
# 122.0,Антоновича (Горького)
#
# 45.0,Метрологічна
#
# 75.0,Калнишевського (Михайло Майорова)
#
# 34.0,Зарічна
#
# 46.0,Тичини
#
# 100.0,Саперно-Слобідська
#
# 99.0,Комарова
#
# 75.0,Б. Житомирська
#
# 62.0,Каховська
#
# 72.0,Оболонська
#
# 116.3,Червоноткацька
#
# 159.0,Драгомирова
#
# 76.0,Автозаводська
#
# 47.32,Тираспільська
#
# 44.0,Щербаківського (Щербакова)
#
# 95.0,Правди
#
# 240.0,Голосіївський (40-річчя Жовтня)
#
# 36.0,Максимовича (Онуфрія Трутенко)
#
# 50.0,Бойчука (Кіквідзе)
#
# 71.0,Тираспільська
#
# 60.51,Університетська
#
# 80.66,Оболонський
#
# 123.0,Ахматової
#
# 74.0,Правди
#
# 81.0,Зарічна
#
# 43.0,Закревського
#
# 84.0,Бориспільська
#
# 46.0,Герцена
#
# 55.0,Балтійський
#
# 136.0,Шаповала (Механізаторів)
#
# 21.31,Глибочицька
#
# 136.0,Салютна
#
# 41.0,Ревуцького
#
# 71.0,Набережно-Рибальська
#
# 57.0,Мар'яненко
#
# 149.0,Павлівська
#
# 50.0,Саперне Поле
#
# 75.0,Русовий
#
# 92.0,Драгомирова
#
# 60.0,Яблонській
#
# 70.99,Гончара
#
# 60.51,Університетська
#
# 55.0,Дніпровська
#
# 83.0,Регенераторна
#
# 55.0,Деміївська
#
# 36.0,Новопольова
#
# 65.0,Бастіонна
#
# 112.0,Сверстюка (Марини Раскової)
#
# 50.0,Героїв Сталінграда
#
# 68.0,Правди
#
# 85.0,Правди
#
# 51.0,Героїв Сталінграда
#
# 46.0,Яблучна
#
# 207.0,Коновальця (Щорса)
#
# 130.0,Героїв Сталінграда
#
# 81.0,Мирного
#
# 41.0,Заболотного
#
# 50.0,Сверстюка (Марини Раскової)
#
# 54.0,Предславинська
#
# 83.0,Заболотного
#
# 81.0,Омельяновича-Павленка (Суворова)
#
# 44.0,Єреванська
#
# 90.0,Чавдар
#
# 79.0,Бойчука (Кіквідзе)
#
# 43.0,Правди
#
# 51.0,Коперника
#
# 126.1,Лебедєва
#
# 54.9,Драгоманова
#
# 110.0,Ахматової
#
# 106.0,Голосіївський (40-річчя Жовтня)
#
# 72.0,Панельна
#
# 122.0,Січових Стрільців (Артема)
#
# 67.0,Заболотного
#
# 273.0,Богомольця
#
# 83.0,Палладіна
#
# 45.0,Перемоги (Брест-Литовський)
#
# 74.6,Богатирська
#
# 26.9,Червоноткацька
#
# 49.0,Зарічна
#
# 84.1,Бажана
#
# 183.0,Воздвиженська
#
# 48.3,Градинська
#
# 76.0,Глибочицька
#
# 160.0,Тургенєвська
#
# 40.82,Тираспільська
#
# 59.5,Ломоносова
#
# 73.0,Гречка
#
# 46.79,Правди
#
# 44.0,Ломоносова
#
# 75.0,Алмазова (Кутузова)
#
# 60.0,Лобановського (Червонозоряний)
#
# 34.0,Наумова
#
# 65.0,Полярна
#
# 190.0,Українки
#
# 240.0,Дарвіна
#
# 85.0,Драгомирова
#
# 48.0,Предславинська
#
# 75.0,Липківського (Урицького)
#
# 60.0,Паньківська
#
# 49.7,Лаврухіна
#
# 47.18,Василенка
#
# 50.0,Зарічна
#
# 71.0,Бендукідзе
#
# 30.34,Цісик (Гамарника)
#
# 68.0,Урлівська
#
# 44.0,Печерський
#
# 48.0,Саперне Поле
#
# 46.0,Крайня
#
# 63.9,Причальна
#
# 92.48,Микільсько-Ботанічна
#
# 63.0,Предславинська
#
# 71.0,Героїв Дніпра
#
# 35.0,Максимовича (Онуфрія Трутенко)
#
# 48.0,Замковецька
#
# 56.0,Симоненко
#
# 206.0,Коновальця (Щорса)
#
# 172.0,Назарівська (Вєтрова)
#
# 45.0,Регенераторна
#
# 85.0,Перемоги (Брест-Литовський)
#
# 49.0,Стеценка
#
# 193.0,Героїв Сталінграда
#
# 41.3,Голосіївський (40-річчя Жовтня)
#
# 43.0,Гавела (Івана Лепсе)
#
# 350.0,Б. Житомирська
#
# 127.0,І. Павла ІІ (Патріса Лумумби)
#
# 77.9,Регенераторна
#
# 180.0,Ковпака
#
# 54.54,Бойчука (Кіквідзе)
#
# 0.0,Максимовича (Онуфрія Трутенко)
#
# 60.0,Курбаса (50-річчя Жовтня)
#
# 60.0,Героїв Сталінграда
#
# 174.0,Вишгородська
#
# 73.0,Урлівська
#
# 93.0,Дегтярівська
#
# 73.2,Харківське
#
# 140.0,Урлівська
#
# 50.0,Перемоги (Брест-Литовський)
#
# 88.0,Ломоносова
#
# 47.8,Заболотного
#
# 43.0,Маккейна (Івана Кудрі)
#
# 72.0,Толстого
#
# 247.0,Солом'янська
#
# 250.0,Героїв Сталінграда
#
# 67.0,Каховська
#
# 81.0,Теремківська
#
# 33.0,Микільсько-Слобідська
#
# 58.3,Тимошенко
#
# 93.0,Зарічна
#
# 109.0,Закревського
#
# 70.05,Конєва
#
# 55.0,Туполєва
#
# 88.0,Сверстюка (Марини Раскової)
#
# 44.2,Соборності (Поєднання)
#
# 150.0,Гедройця (Тверська)
#
# 87.0,Сверстюка (Марини Раскової)
#
# 275.0,Жилянська
#
# 80.0,Кольцова
#
# 54.0,Драгоманова
#
# 43.0,Перемоги (Брест-Литовський)
#
# 94.0,Драгоманова
#
# 42.0,Маккейна (Івана Кудрі)
#
# 33.8,Наддніпрянське
#
# 116.0,Урлівська
#
# 76.0,Богданівська
#
# 59.0,Зодчих
#
# 200.0,Тургенєвська
#
# 70.0,Герцена
#
# 75.5,Руденко
#
# 150.0,Грушевського
#
# 162.0,Миколи Голого (Лебедєва-Кумача)
#
# 45.0,Омельяновича-Павленка (Суворова)
#
# 62.0,Північно-Сирецька
#
# 75.0,Б. Житомирська
#
# 90.4,Українки
#
# 70.0,Тютюнника (Анрі Барбюса)
#
# 95.0,Данченко
#
# 555.0,Ковпака
#
# 37.62,Радченко
#
# 93.0,Лебедєва
#
# 55.0,Драгомирова
#
# 102.0,Драгомирова
#
# 94.0,Набережно-Рибальська
#
# 41.0,Сергія Колоса (Леніна)
#
# 77.5,Причальна
#
# 87.98,Перемоги (Брест-Литовський)
#
# 65.91,Визволителів
#
# 67.0,Сверстюка (Марини Раскової)
#
# 127.24,Набережно-Рибальська
#
# 31.0,Порика
#
# 87.0,Гречка
#
# 82.0,Зарічна
#
# 50.0,Бажана
#
# 40.0,Радченко
#
# 70.0,Михайлівська
#
# 75.0,Ломоносова
#
# 96.0,Щербаківського (Щербакова)
#
# 56.0,Симоненко
#
# 43.0,Дніпровська
#
# 119.0,Драгомирова
#
# 43.0,Андріївська
#
# 22.0,Копилівська
#
# 105.0,Урлівська
#
# 44.0,Єреванська
#
# 69.0,Драгоманова
#
# 45.0,ЖК Stanford
#
# 95.0,Правди
#
# 28.0,Комарова
#
# 40.0,Правди
#
# 161.0,Толстого
#
# 100.0,Харківське
#
# 65.0,ЖК Лебединий
#
# 213.0,Паторжинського
#
# 62.0,Повітрофлотський
#
# 63.0,Правди
#
# 90.0,Алмазова (Кутузова)
#
# 39.0,ЖК 52 Перлина (Pechersk Plaza)
#
# 73.0,Малиновського
#
# 34.0,Райдужна
#
# 50.0,Маланюка (Степана Сагайдака)
#
# 39.0,Дінця
#
# 55.0,Федорова
#
# 58.0,Срібнокільська
#
# 52.0,ЖК Nordica Residence
#
# 92.0,Липківського (Урицького)
#
# 68.0,Дінця
#
# 84.7,Маланюка (Степана Сагайдака)
#
# 65.0,Перемоги (Брест-Литовський)
#
# 145.0,Парково-Сирецька (Шамрило Тимофія)
#
# 58.0,Ломоносова
#
# 76.0,Маяковського
#
# 46.0,Багговутівська
#
# 88.0,Дарницький
#
# 93.3,Чавдар
#
# 41.6,Наддніпрянське
#
# 58.0,Героїв Сталінграда
#
# 52.0,Правди
#
# 70.0,Конєва
#
# 65.0,Воскресенська
#
# 47.0,Саперне Поле
#
# 79.0,Ясинуватський
#
# 34.0,Потапова
#
# 98.0,Кондратюка
#
# 50.0,Чаадаєва
#
# 70.0,Пчілки
#
# 45.0,Гречка
#
# 150.0,Саперне Поле
#
# 66.0,Глибочицька
#
# 65.0,Причальна
#
# 130.0,Болсунівська (Сергія Струтинського)
#
# 70.0,Сікорського (Танкова)
#
# 60.0,Костанайська
#
# 78.0,Богатирська
#
# 53.0,Малоземельна
#
# 65.0,Спаська
#
# 87.3,Прорізна
#
# 69.0,Милославська
#
# 61.0,ЖК Бульвар Фонтанів
#
# 81.0,Драгомирова
#
# 57.0,Гавела (Івана Лепсе)
#
# 48.0,Данченко
#
# 47.0,Шолуденко
#
# 93.0,Михайлівський
#
# 49.0,ЖК CRYSTAL RESIDENCE
#
# 66.25,Бойчука (Кіквідзе)
#
# 72.0,Антоновича (Горького)
#
# 65.0,Ольжича
#
# 49.0,Ревуцького
#
# 31.0,ЖК Берег Дніпра
#
# 41.0,Практична
#
# 53.0,Жмаченко
#
# 77.0,Скрипника (Микола Островського)
#
# 100.0,Коновальця (Щорса)
#
# 55.0,Бажана
#
# 58.0,Григоренко
#
# 52.0,ЖК Manhattan city
#
# 312.0,Драгомирова
#
# 87.0,Данченко
#
# 145.0,Бутишев (Андрія Іванова)
#
# 50.0,Маккейна (Івана Кудрі)
#
# 125.0,Лейпцизька
#
# 43.0,Правди
#
# 130.0,Болсунівська (Сергія Струтинського)
#
# 81.0,Драгомирова
#
# 208.0,Старонаводницька
#
# 306.0,Протасів Яр
#
# 54.0,Дніпровська
#
# 105.0,Лобановського (Червонозоряний)
#
# 69.0,Дніпровська
#
# 66.0,Павлівська
#
# 67.0,Ломоносова
#
# 46.0,Ахматової
#
# 104.0,Вернадського
#
# 55.0,Балтійський
#
# 92.0,Липківського (Урицького)
#
# 86.0,Резницька
#
# 87.0,Каховська
#
# 43.2,Закревського
#
# 86.74,Сверстюка (Марини Раскової)
#
# 90.77,Правди
#
# 48.6,Героїв Сталінграда
#
# 86.38,Правди
#
# 51.0,Героїв Дніпра
#
# 250.0,Б. Житомирська
#
# 25.0,Корольова
#
# 42.0,Крушельницької
#
# 46.0,Регенераторна
#
# 127.0,Голосіївська
#
# 46.0,Старокиївська
#
# 66.0,Дніпровська
#
# 122.8,Героїв Сталінграда
#
# 70.0,Сікорського (Танкова)
#
# 81.0,Саксаганського
#
# 54.9,Драгоманова
#
# 41.3,Героїв Дніпра
#
# 85.0,Велика Васильківська (Червоноармійська)
#
# 79.0,Малевича (Василя Боженка)
#
# 83.0,Юрківська
#
# 38.0,Нагірна
#
# 160.0,Щекавицька
#
# 37.0,Жуковського
#
# 198.3,Павлівська
#
# 108.0,Маккейна (Івана Кудрі)
#
# 150.0,Бальзака
#
# 72.0,Приозерна
#
# 130.9,Інститутська
#
# 41.0,Правди
#
# 53.0,Коновальця (Щорса)
#
# 43.0,Зарічна
#
# 46.5,Стражеска
#
# 71.0,Харківське
#
# 56.0,Жилянська
#
# 118.0,Бориспільська
#
# 80.0,Воскресенська
#
# 85.0,Дігтярна
#
# 104.0,Сім'ї Прахових (Гайдара)
#
# 60.27,Богатирська
#
# 47.3,Мурашка
#
# 31.0,Щусєва
#
# 90.0,Андрющенко
#
# 104.0,Ділова (Георгія Димитрова)
#
# 46.0,Перемоги (Брест-Литовський)
#
# 103.0,Маккейна (Івана Кудрі)
#
# 38.0,Драйзера
#
# 111.0,Срібнокільська
#
# 90.0,Туманяна
#
# 55.8,Відрадний (Чубаря)
#
# 79.0,Попова
#
# 74.0,Зелена
#
# 46.0,Курчатова
#
# 49.0,Архипенко (Залки Мате)
#
# 76.0,Здолбунівська
#
# 103.0,Градинська
#
# 46.5,Дніпровська
#
# 110.0,Теремківська
#
# 70.0,Українки
#
# 95.09,Ушинського
#
# 60.0,Бондарський
#
# 93.0,Милославська
#
# 130.0,Героїв Сталінграда
#
# 25.0,Практична
#
# 55.0,Герцена
#
# 171.0,Тургенєвська
#
# 43.0,Магнітогорська
#
# 48.0,Героїв Сталінграда
#
# 87.0,Полтавська
#
# 53.0,Перемоги (Брест-Литовський)
#
# 84.0,Річкова
#
# 46.0,Ярославська
#
# 52.0,Деміївська
#
# 91.0,Саперне Поле
#
# 65.0,Каховська
#
# 82.0,Бойчука (Кіквідзе)
#
# 88.0,Хрещатик
#
# 41.0,Червоноткацька
#
# 150.0,Грушевського
#
# 73.0,Драгоманова
#
# 81.0,Каховська
#
# 50.0,Антоновича (Горького)
#
# 37.0,Максимовича (Онуфрія Трутенко)
#
# 60.0,Драгомирова
#
# 30.0,ЖК POLARIS Home&Plaza
#
# 63.0,Комфортна та сучасна
#
# 213.0,Паторжинського
#
# 73.7,Голосіївський (40-річчя Жовтня)
#
# 45.1,Харківське
#
# 87.0,Йорданська (Гавро Лайоша)
#
# 68.0,ЖК Ярославів Град
#
# 103.0,Вільямса
#
# 79.97,Жмаченко
#
# 91.0,Радченко
#
# 64.0,Ясинуватський
#
# 61.0,ЖК Бульвар Фонтанів
#
# 94.0,Вишгородська
#
# 111.0,Вишгородська
#
# 46.0,Герцена
#
# 40.0,Предславинська
#
# 70.0,Вербицького
#
# 84.0,Тарасівська
#
# 53.0,ЖК Olympic Park
#
# 80.0,Липківського (Урицького)
#
# 70.0,Кирилівська (Фрунзе)
#
# 137.0,Маршака
#
# 51.0,Берковецька
#
# 52.0,Драгоманова
#
# 248.0,Хмельницького
#
# 52.0,Драгоманова
#
# 74.0,Сверстюка (Марини Раскової)
#
# 108.0,Лисянська
#
# 111.1,Антоновича (Горького)
#
# 123.89,Максимовича (Онуфрія Трутенко)
#
# 55.0,Дніпровська
#
# 67.0,Васильківська
#
# 70.0,Панельна
#
# 88.0,Драгомирова
#
# 24.0,Виборзька
#
# 42.8,Гулака
#
# 96.19,Маланюка (Степана Сагайдака)
#
# 46.0,Антоновича (Горького)
#
# 250.0,Болсунівська (Сергія Струтинського)
#
# 37.0,Каховська
#
# 51.0,Осокорська
#
# 61.0,Липківського (Урицького)
#
# 110.0,Срібнокільська
#
# 64.0,Гавела (Івана Лепсе)
#
# 32.1,Теліги
#
# 110.0,Ахматової
#
# 51.0,Перемоги (Брест-Литовський)
#
# 70.0,Саксаганського
#
# 45.0,Українки
#
# 74.2,Радистів
#
# 70.0,Лисенка
#
# 41.08,Максимовича (Онуфрія Трутенко)
#
# 80.0,Перемоги (Брест-Литовський)
#
# 40.0,Дніпровська
#
# 54.0,Коновальця (Щорса)
#
# 98.0,Дніпровська
#
# 185.0,Золотоустівська
#
# 48.75,Північно-Сирецька
#
# 73.0,Дяченка
#
# 110.0,Драгомирова
#
# 40.0,Лобачевського
#
# 165.0,Толстого
#
# 74.0,Вербицького
#
# 57.0,І. Павла ІІ (Патріса Лумумби)
#
# 70.0,Бережанська
#
# 86.72,Сверстюка (Марини Раскової)
#
# 78.0,Героїв Сталінграда
#
# 58.7,Перемоги (Брест-Литовський)
#
# 92.0,Львівська
#
# 54.0,Драгоманова
#
# 85.0,Перемоги (Брест-Литовський)
#
# 350.0,Здолбунівська
#
# 80.1,Перемоги (Брест-Литовський)
#
# 170.0,Антоновича (Горького)
#
# 48.0,Українки
#
# 55.0,Наумова
#
# 230.0,Богомольця
#
# 155.72,Бойчука (Кіквідзе)
#
# 81.6,Бойчука (Кіквідзе)
#
# 91.2,Голосіївська
#
# 120.3,Малевича (Василя Боженка)
#
# 29.0,Сім'ї Ідзіковських (Михайло Мішина)
#
# 67.0,Володимирська
#
# 72.0,Балтійський
#
# 55.0,Феодосійська
#
# 47.24,Кібальчича
#
# 49.31,Ревуцького
#
# 62.0,Предславинська
#
# 130.0,Коновальця (Щорса)
#
# 67.0,Антоновича (Горького)
#
# 42.0,Машинобудівний
#
# 74.0,Гаврилишина (Ванди Василевської)
#
# 88.0,Харківське
#
# 49.0,Ломоносова
#
# 42.0,Сверстюка (Марини Раскової)
#
# 49.0,Гонгадзе (Машинобудівна)
#
# 55.0,Повітрофлотський
#
# 42.0,Маккейна (Івана Кудрі)
#
# 142.0,Старонаводницька
#
# 50.0,Практична
#
# 32.0,Оболонський
#
# 44.0,Причальна
#
# 52.0,Микільсько-Ботанічна
#
# 156.0,Бойчука (Кіквідзе)
#
# 123.0,Глибочицька
#
# 165.0,Драгомирова
#
# 66.0,Глибочицька
#
# 82.2,Велика Васильківська (Червоноармійська)
#
# 41.0,Тимошенко
#
# 42.0,Ентузіастів
#
# 61.0,Іпсілантіївський (Аїстова)
#
# 80.0,Туманяна
#
# 119.0,Драгомирова
#
# 53.0,Чорновола (Косіора)
#
# 63.0,Болсунівська (Сергія Струтинського)
#
# 43.0,Підвисоцького
#
# 86.0,Оболонський
#
# 120.0,Драгомирова
#
# 108.0,Котельникова
#
# 94.0,Нижньоключова
#
# 115.0,Дніпровська
#
# 36.25,Радченко
#
# 55.0,Ясногірська
#
# 62.0,Каховська
#
# 53.0,ЖК Washington Concept House
#
# 48.5,Дмитрівська
#
# 122.0,Оболонська набережна
#
# 90.0,Чорновола (Косіора)
#
# 55.0,Дружби народів
#
# 40.0,Метрологічна
#
# 46.0,ЖК Forward
#
# 340.0,Коновальця (Щорса)
#
# 41.0,Наддніпрянське
#
# 47.0,Микільський (Січневий)
#
# 55.0,Коласа
#
# 79.0,ЖК Dibrova Park
#
# 65.0,Вернадського
#
# 32.0,Калнишевського (Михайло Майорова)
#
# 63.0,Повітрофлотський
#
# 50.0,Микільсько-Слобідська
#
# 36.0,Перемоги (Брест-Литовський)
#
# 35.0,Березнева
#
# 52.0,ЖК Krauss Gallery
#
# 50.0,Пчілки
#
# 165.0,Героїв Сталінграда
#
# 71.0,Перемоги (Брест-Литовський)
#
# 110.0,Ломоносова
#
# 102.0,Протасів Яр
#
# 80.0,Нижньоключова
#
# 60.0,Кулібіна
#
# 70.0,Пчілки
#
# 80.0,Симиренко
#
# 84.0,Регенераторна
#
# 72.0,Ахматової
#
# 96.0,Коновальця (Щорса)
#
# 32.0,Віфлеємська (Академіка Шліхтера)
#
# 113.0,Гмирі
#
# 119.0,Голосіївська
#
# 61.0,Вернадського
#
# 75.0,Соборності (Поєднання)
#
# 54.83,Антоновича (Горького)
#
# 82.0,Регенераторна
#
# 98.0,Калнишевського (Михайло Майорова)
#
# 32.0,Стеценка
#
# 37.0,Кольцова
#
# 96.0,Палладіна
#
# 74.0,Тютюнника (Анрі Барбюса)
#
# 54.0,Львівська
#
# 88.0,Мар'яненко
#
# 125.2,Вишгородська
#
# 65.0,Дніпровська
#
# 50.0,Андріївський
#
# 100.0,Урлівська
#
# 125.0,Гавела (Івана Лепсе)
#
# 55.0,Балтійський
#
# 55.0,Багговутівська
#
# 49.0,ЖК CRYSTAL RESIDENCE
#
# 51.89,Балтійський
#
# 55.0,Воробйова (Курська)
#
# 60.4,Гончара
#
# 130.0,Лейпцизька
#
# 40.0,Тираспільська
#
# 56.0,ЖК Diadans
#
# 75.0,Краківська
#
# 98.0,Сабурова
#
# 58.4,Глибочицька
#
# 51.0,Героїв Сталінграда
#
# 32.0,ЖК Chalet
#
# 308.0,Івана Мазепи (Січневого повстання)
#
# 30.0,Радченко
#
# 90.0,Алмазова (Кутузова)
#
# 61.0,Городецького
#
# 105.0,Маланюка (Степана Сагайдака)
#
# 32.0,Каховська
#
# 27.0,ЖК Svitlo Park
#
# 37.0,Вишняківська
#
# 76.0,Миропільська
#
# 75.0,Феодосійська
#
# 65.0,Малевича (Василя Боженка)
#
# 114.0,Тютюнника (Анрі Барбюса)
#
# 152.0,Коновальця (Щорса)
#
# 115.0,Дніпровська
#
# 89.0,Маланюка (Степана Сагайдака)
#
# 70.0,Жилянська
#
# 84.2,Оболонський
#
# 157.6,Павлівська
#
# 85.0,Крутий
#
# 83.0,Берковецька
#
# 119.0,Оболонська набережна
#
# 100.0,Зарічна
#
# 42.0,Юнацька
#
# 44.0,Правди
#
# 262.0,Драгомирова
#
# 125.0,Драгомирова
#
# 35.0,Крайня
#
# 51.0,Харківське
#
# 66.0,Правди
#
# 68.0,Перемоги (Брест-Литовський)
#
# 70.0,Братиславська
#
# 113.0,Краснопільська
#
# 66.2,Гавела (Івана Лепсе)
#
# 108.0,Тютюнника (Анрі Барбюса)
#
# 46.0,Північно-Сирецька
#
# 60.0,Гарматна
#
# 125.0,Гавела (Івана Лепсе)
#
# 58.0,Героїв Сталінграда
#
# 198.5,Бойчука (Кіквідзе)
#
# 120.0,Кривоноса
#
# 68.0,ЖК Ярославів Град
#
# 42.0,Бориспільська
#
# 69.0,Ревуцького
#
# 86.0,Маккейна (Івана Кудрі)
#
# 32.0,Радченко
#
# 144.3,Чаадаєва
#
# 52.0,ЖК Manhattan city
#
# 92.0,Липківського (Урицького)
#
# 60.0,Клавдіївська
#
# 81.09,Заболотного
#
# 189.0,Ломоносова
#
# 59.0,ЖК Володимирський
#
# 69.0,Дніпровська
#
# 48.0,Поліська
#
# 62.0,Іскрівська
#
# 87.0,Ризька
#
# 83.0,Правди
#
# 65.0,Антоновича (Горького)
#
# 37.0,Житловий район
#
# 56.0,Салютна
#
# 64.0,Омельяновича-Павленка (Суворова)
#
# 78.0,Стуса
#
# 64.0,Українки
#
# 37.0,Вишняківська
#
# 117.0,Тютюнника (Анрі Барбюса)
#
# 45.0,Виноградний
#
# 42.0,Перемоги (Брест-Литовський)
#
# 115.0,Дніпровська
#
# 52.1,Перемоги (Брест-Литовський)
#
# 76.0,Туполєва
#
# 115.0,Старонаводницька
#
# 40.22,Балтійський
#
# 59.62,Бойчука (Кіквідзе)
#
# 44.0,Бастіонна
#
# 90.0,Ревуцького
#
# 68.0,Болсунівська (Сергія Струтинського)
#
# 46.22,Повітрофлотський
#
# 106.2,Золотоустівська
#
# 85.0,Русовий
#
# 130.0,Саксаганського
#
# 45.0,Теремківська
#
# 46.0,Кібальчича
#
# 40.95,Радченко
#
# 112.0,Голосіївський (40-річчя Жовтня)
#
# 55.2,Лисогірський
#
# 86.2,Гоголівська
#
# 55.0,Тютюнника (Анрі Барбюса)
#
# 41.0,Солом'янська
#
# 75.0,Героїв Сталінграда
#
# 125.0,Глибочицька
#
# 124.14,Жилянська
#
# 78.9,Доброхотова
#
# 158.0,Жилянська
#
# 44.0,Відрадний (Чубаря)
#
# 48.0,Предславинська
#
# 61.0,Іпсілантіївський (Аїстова)
#
# 66.0,Глибочицька
#
# 133.0,Голосіївський (40-річчя Жовтня)
#
# 47.0,Оболонський
#
# 135.0,Багговутівська
#
# 35.0,Правди
#
# 44.0,Причальна
#
# 64.8,Бойчука (Кіквідзе)
#
# 41.0,Радистів
#
# 51.0,Лук'янівська
#
# 55.0,Правди
#
# 81.0,Шевельова (Микола Руднєва)
#
# 82.0,Героїв Сталінграда
#
# 89.0,Єфремова (Уборевича Командарма)
#
# 44.3,Балтійський
#
# 44.0,Бойчука (Кіквідзе)
#
# 358.0,Івана Мазепи (Січневого повстання)
#
# 95.0,Гришко
#
# 68.0,Сім'ї Сосніних
#
# 112.0,Харківське
#
# 38.0,Будищанська
#
# 44.0,МФК Intergal City
#
# 72.4,Мечнікова
#
# 40.0,Дніпровська
#
# 70.0,Маяковського
#
# 57.51,Гончара
#
# 63.0,І. Павла ІІ (Патріса Лумумби)
#
# 42.0,ЖК Rusaniv Residence
#
# 120.0,Героїв Сталінграда
#
# 120.0,Драгомирова
#
# 70.0,Драгомирова
#
# 160.0,Героїв Сталінграда
#
# 53.0,ЖК Olympic Park
#
# 222.0,Драгомирова
#
# 104.0,Бессарабська
#
# 44.0,Ломоносова
#
# 47.0,Тираспільська
#
# 200.3,Франка
#
# 72.0,Шовковична
#
# 31.0,ЖК Берег Дніпра
#
# 66.0,Голосіївський (40-річчя Жовтня)
#
# 120.0,Ломоносова
#
# 95.0,Героїв Сталінграда
#
# 112.0,Регенераторна
#
# 50.0,Салютна
#
# 126.0,Саперне Поле

# %% [markdown]
# #### імпортувати в БД отриманий файл 'street_flat_propery.csv' через CLI
# - __sqlite3 districts.db__ - запустити SQLite та відкрити БД
# - __.mode csv__ - перевести БД для роботи з csv-файлами
# - __.import street_flat_propery.csv street_flat_propery__ - створює таблицю _street_flat_propery_ та завантажує в неї вміст файлу _street_flat_propery.csv_
# - __SELECT * FROM street_flat_propery LIMIT 10;__ - вивести 10 записів для перевірки
# - __.quit__ - завершити роботу з CLI SQLite

# %%
# Підключитись до БД 'districts.db' в якій є прив'язка вулиць до районів 
conn = sqlite3.connect("districts.db")

# створити відповідний курсор
cur  = conn.cursor()

# %%
# для перевірки виведіть 10 записів з таблиці 'street_district'
street_dis = cur.execute("SELECT * FROM street_district LIMIT 10")

# будуємо список записів за допомогою метода `fetchall()`
streets_list = street_dis.fetchall()

print(streets_list[7])

streets_list = [(sl[i].strip() for i in range(len(sl))) for sl in streets_list]


_ = [print(x) for x in streets_list]
# Out:
# ('Автозаводський ', 'провулок', 'Оболонський')
# <generator object <listcomp>.<genexpr> at 0x0000023AF8E40F68>
# <generator object <listcomp>.<genexpr> at 0x0000023AF8E40D58>
# <generator object <listcomp>.<genexpr> at 0x0000023AF8EAC0F8>
# <generator object <listcomp>.<genexpr> at 0x0000023AF8EAC048>
# <generator object <listcomp>.<genexpr> at 0x0000023AF8EAC150>
# <generator object <listcomp>.<genexpr> at 0x0000023AF8EC7DB0>
# <generator object <listcomp>.<genexpr> at 0x0000023AF8EC7EB8>
# <generator object <listcomp>.<genexpr> at 0x0000023AF8EC7E60>
# <generator object <listcomp>.<genexpr> at 0x0000023AF8EC7F10>
# <generator object <listcomp>.<genexpr> at 0x0000023AF8EC7F68>

# %%
# побудувати запит на створення таблиці 'result' з 3-ма полями:
#     district - текстове
#     street - текстове
#     property - числове
stmt = "CREATE TABLE IF NOT EXISTS result \
              (district TEXT,         \
               street TEXT,            \
               property REAL);"

# %%
# виконати запит
cur.execute(stmt)

# %%
# перевірити схему таблиці
cur.execute ("SELECT name FROM PRAGMA_TABLE_INFO('result');").fetchall()
# Out:
# [('district',), ('street',), ('property',)]

# %%
# створити запит на злиття таблиці 'street_flat_propery' та 'street_district' 
# по полю 'street'
stmt_join = "SELECT street_district.district, street_flat_propery.street, street_flat_propery.total_area FROM  \
             street_flat_propery LEFT JOIN street_district ON street_flat_propery.street = street_district.street "

# %%
# перевірити запит
cur.execute(stmt_join).fetchall()
# Out:
# [(None, 'Малиновського', '73.0'),
#  (None, "Сім'ї Сосніних", '110.27'),
#  (None, 'Лобановського (Червонозоряний)', '100.0'),
#  (None, 'Руставелі', '58.0'),
#  ('Голосіївський', 'Ломоносова', '79.0'),
#  ('Печерський', 'Інститутська', '138.7'),
#  (None, 'Антоновича (Горького)', '201.4'),
#  ('Оболонський', 'Дніпровська', '87.0'),
#  ('Печерський', 'Предславинська', '40.0'),
#  (None, 'Коперника', '51.0'),
#  (None, 'Драгомирова', '48.0'),
#  (None, 'Драгомирова', '85.0'),
#  ('Дарницький', 'Ревуцького', '76.0'),
#  ('Деснянський', 'Пожарського', '56.0'),
#  ('Дніпровський', 'Пожарського', '56.0'),
#  (None, 'Гмирі', '38.0'),
#  ('Дарницький', 'Приозерна', '70.0'),
#  ('Оболонський', 'Приозерна', '70.0'),
#  (None, 'Коперника', '103.0'),
#  ('Подільський, Шевченківський', 'Стеценка', '56.44'),
#  ('Деснянський', 'Каштанова', '69.0'),
#  ('Подільський', 'Правди', '47.39'),
#  ('Дарницький', 'Трускавецька', '50.0'),
#  (None, 'Наумова', '64.0'),
#  (None, 'Лобановського (Червонозоряний)', '96.0'),
#  ('Шевченківський', 'Салютна', '46.0'),
#  (None, 'Василенка', '44.0'),
#  (None, 'Палладіна', '100.0'),
#  (None, 'Міт. А. Шептицького (Анатолія Луначарського)', '240.0'),
#  ('Оболонський', 'Балтійський', '72.1'),
#  ('Оболонський', 'Дніпровська', '75.0'),
#  ('Печерський', 'Станіславського', '78.0'),
#  (None, 'Драгомирова', '126.0'),
#  ('Подільський', 'Правди', '93.0'),
#  (None, 'Максимовича (Онуфрія Трутенко)', '63.0'),
#  (None, 'ЖК PARKLAND', '44.0'),
#  ('Дарницький', 'Причальна', '67.92'),
#  (None, 'Перемоги (Брест-Литовський)', '52.0'),
#  ("Солом'янський", 'Богданівська', '99.0'),
#  ('Печерський', 'Тверський', '96.0'),
#  ('Подільський', 'Набережно-Хрещатицька', '65.0'),
#  (None, 'Липківського (Урицького)', '50.0'),
#  ('Подільський', 'Правди', '76.0'),
#  ('Оболонський', 'Дніпровська', '45.3'),
#  (None, 'Тютюнника (Анрі Барбюса)', '99.0'),
#  (None, '3-кімнатна квартира 74', '74.7'),
#  ('Подільський', 'Правди', '59.0'),
#  (None, 'Закревського', '73.0'),
#  ('Печерський', 'Тверський', '62.0'),
#  (None, 'Туполєва', '76.0'),
#  ('Шевченківський', 'Глибочицька', '76.0'),
#  (None, 'Січових Стрільців (Артема)', '210.0'),
#  ('Подільський, Оболонський', 'Вишгородська', '33.0'),
#  (None, 'Бойчука (Кіквідзе)', '66.8'),
#  ('Печерський', 'Предславинська', '62.0'),
#  (None, 'Вадима Гетьмана', '102.1'),
#  ('Дарницький', 'Драгоманова', '110.0'),
#  ("Солом'янський", 'Ніжинська', '51.0'),
#  (None, 'Кучера', '44.0'),
#  (None, 'Голосіївський (40-річчя Жовтня)', '91.0'),
#  (None, 'Іллєнко (Мельникова)', '28.0'),
#  (None, 'Бойчука (Кіквідзе)', '56.0'),
#  ('Шевченківський', 'Половецька', '67.3'),
#  ('Голосіївський, Шевченківський', 'Володимирська', '100.0'),
#  (None, 'Гончара', '82.0'),
#  (None, 'Антоновича (Горького)', '122.0'),
#  ('Голосіївський', 'Метрологічна', '45.0'),
#  (None, 'Калнишевського (Михайло Майорова)', '75.0'),
#  ('Дарницький', 'Зарічна', '34.0'),
#  (None, 'Тичини', '46.0'),
#  ('Голосіївський', 'Саперно-Слобідська', '100.0'),
#  (None, 'Комарова', '99.0'),
#  (None, 'Б. Житомирська', '75.0'),
#  ('Дніпровський', 'Каховська', '62.0'),
#  ('Шевченківський', 'Глибочицька', '76.0'),
#  (None, 'Січових Стрільців (Артема)', '210.0'),
#  ('Подільський, Оболонський', 'Вишгородська', '33.0'),
#  (None, 'Бойчука (Кіквідзе)', '66.8'),
#  ('Печерський', 'Предславинська', '62.0'),
#  (None, 'Вадима Гетьмана', '102.1'),
#  ('Дарницький', 'Драгоманова', '110.0'),
#  ("Солом'янський", 'Ніжинська', '51.0'),
#  (None, 'Кучера', '44.0'),
#  (None, 'Голосіївський (40-річчя Жовтня)', '91.0'),
#  (None, 'Іллєнко (Мельникова)', '28.0'),
#  (None, 'Бойчука (Кіквідзе)', '56.0'),
#  ('Шевченківський', 'Половецька', '67.3'),
#  ('Голосіївський, Шевченківський', 'Володимирська', '100.0'),
#  (None, 'Гончара', '82.0'),
#  (None, 'Антоновича (Горького)', '122.0'),
#  ('Голосіївський', 'Метрологічна', '45.0'),
#  (None, 'Калнишевського (Михайло Майорова)', '75.0'),
#  ('Дарницький', 'Зарічна', '34.0'),
#  (None, 'Тичини', '46.0'),
#  ('Голосіївський', 'Саперно-Слобідська', '100.0'),
#  (None, 'Комарова', '99.0'),
#  (None, 'Б. Житомирська', '75.0'),
#  ('Дніпровський', 'Каховська', '62.0'),
#  ('Оболонський', 'Оболонська', '72.0'),
#  ('Оболонський', 'Оболонська', '72.0'),
#  ('Подільський', 'Оболонська', '72.0'),
#  (None, 'Червоноткацька', '116.3'),
#  (None, 'Драгомирова', '159.0'),
#  ('Оболонський', 'Автозаводська', '76.0'),
#  (None, 'Тираспільська', '47.32'),
#  (None, 'Щербаківського (Щербакова)', '44.0'),
#  ('Подільський', 'Правди', '95.0'),
#  (None, 'Голосіївський (40-річчя Жовтня)', '240.0'),
#  (None, 'Максимовича (Онуфрія Трутенко)', '36.0'),
#  (None, 'Бойчука (Кіквідзе)', '50.0'),
#  (None, 'Тираспільська', '71.0'),
#  ("Солом'янський", 'Університетська', '60.51'),
#  ('Оболонський', 'Оболонський', '80.66'),
#  (None, 'Ахматової', '123.0'),
#  ('Подільський', 'Правди', '74.0'),
#  ('Дарницький', 'Зарічна', '81.0'),
#  (None, 'Закревського', '43.0'),
#  ('Дарницький', 'Бориспільська', '84.0'),
#  ('Шевченківський', 'Герцена', '46.0'),
#  ('Шевченківський', 'Герцена', '46.0'),
#  ('Шевченківський', 'Герцена', '46.0'),
#  ('Оболонський', 'Балтійський', '55.0'),
#  (None, 'Шаповала (Механізаторів)', '136.0'),
#  ('Шевченківський', 'Глибочицька', '21.31'),
#  ('Шевченківський', 'Салютна', '136.0'),
#  ('Дарницький', 'Ревуцького', '41.0'),
#  ('Подільський', 'Набережно-Рибальська', '71.0'),
#  (None, "Мар'яненко", '57.0'),
#  ('Шевченківський', 'Павлівська', '149.0'),
#  ('Печерський', 'Саперне Поле', '50.0'),
#  (None, 'Русовий', '75.0'),
#  (None, 'Драгомирова', '92.0'),
#  (None, 'Яблонській', '60.0'),
#  (None, 'Гончара', '70.99'),
#  ("Солом'янський", 'Університетська', '60.51'),
#  ('Оболонський', 'Дніпровська', '55.0'),
#  ('Дніпровський', 'Регенераторна', '83.0'),
#  ('Голосіївський', 'Деміївська', '55.0'),
#  ('Голосіївський', 'Деміївська', '55.0'),
#  ("Солом'янський", 'Новопольова', '36.0'),
#  ('Печерський', 'Бастіонна', '65.0'),
#  (None, 'Сверстюка (Марини Раскової)', '112.0'),
#  ('Оболонський', 'Героїв Сталінграда', '50.0'),
#  ('Подільський', 'Правди', '68.0'),
#  ('Подільський', 'Правди', '85.0'),
#  ('Оболонський', 'Героїв Сталінграда', '51.0'),
#  (None, 'Яблучна', '46.0'),
#  (None, 'Коновальця (Щорса)', '207.0'),
#  ('Оболонський', 'Героїв Сталінграда', '130.0'),
#  (None, 'Мирного', '81.0'),
#  (None, 'Заболотного', '41.0'),
#  (None, 'Сверстюка (Марини Раскової)', '50.0'),
#  ('Печерський', 'Предславинська', '54.0'),
#  (None, 'Заболотного', '83.0'),
#  (None, 'Омельяновича-Павленка (Суворова)', '81.0'),
#  ("Солом'янський", 'Єреванська', '44.0'),
#  (None, 'Чавдар', '90.0'),
#  (None, 'Бойчука (Кіквідзе)', '79.0'),
#  ('Подільський', 'Правди', '43.0'),
#  (None, 'Коперника', '51.0'),
#  (None, 'Лебедєва', '126.1'),
#  ('Дарницький', 'Драгоманова', '54.9'),
#  (None, 'Ахматової', '110.0'),
#  (None, 'Голосіївський (40-річчя Жовтня)', '106.0'),
#  (None, 'Панельна', '72.0'),
#  (None, 'Січових Стрільців (Артема)', '122.0'),
#  (None, 'Заболотного', '67.0'),
#  (None, 'Богомольця', '273.0'),
#  (None, 'Палладіна', '83.0'),
#  (None, 'Перемоги (Брест-Литовський)', '45.0'),
#  ('Оболонський', 'Богатирська', '74.6'),
#  (None, 'Червоноткацька', '26.9'),
#  ('Дарницький', 'Зарічна', '49.0'),
#  (None, 'Бажана', '84.1'),
#  ('Подільський', 'Воздвиженська', '183.0'),
#  ('Деснянський', 'Градинська', '48.3'),
#  ('Шевченківський', 'Глибочицька', '76.0'),
#  ('Шевченківський', 'Тургенєвська', '160.0'),
#  (None, 'Тираспільська', '40.82'),
#  ('Голосіївський', 'Ломоносова', '59.5'),
#  (None, 'Гречка', '73.0'),
#  ('Подільський', 'Правди', '46.79'),
#  ('Голосіївський', 'Ломоносова', '44.0'),
#  (None, 'Алмазова (Кутузова)', '75.0'),
#  (None, 'Лобановського (Червонозоряний)', '60.0'),
#  (None, 'Наумова', '34.0'),
#  ('Оболонський', 'Полярна', '65.0'),
#  (None, 'Українки', '190.0'),
#  ('Печерський', 'Дарвіна', '240.0'),
#  (None, 'Драгомирова', '85.0'),
#  ('Печерський', 'Предславинська', '48.0'),
#  (None, 'Липківського (Урицького)', '75.0'),
#  ('Голосіївський', 'Паньківська', '60.0'),
#  (None, 'Лаврухіна', '49.7'),
#  (None, 'Василенка', '47.18'),
#  ('Дарницький', 'Зарічна', '50.0'),
#  (None, 'Бендукідзе', '71.0'),
#  (None, 'Цісик (Гамарника)', '30.34'),
#  ('Дарницький', 'Урлівська', '68.0'),
#  ('Печерський', 'Печерський', '44.0'),
#  ('Печерський', 'Саперне Поле', '48.0'),
#  ('Деснянський', 'Крайня', '46.0'),
#  ('Дарницький', 'Причальна', '63.9'),
#  ('Голосіївський', 'Микільсько-Ботанічна', '92.48'),
#  ('Печерський', 'Предславинська', '63.0'),
#  ('Оболонський', 'Героїв Дніпра', '71.0'),
#  (None, 'Максимовича (Онуфрія Трутенко)', '35.0'),
#  ('Подільський', 'Замковецька', '48.0'),
#  (None, 'Симоненко', '56.0'),
#  (None, 'Коновальця (Щорса)', '206.0'),
#  (None, 'Назарівська (Вєтрова)', '172.0'),
#  ('Дніпровський', 'Регенераторна', '45.0'),
#  (None, 'Перемоги (Брест-Литовський)', '85.0'),
#  ('Подільський, Шевченківський', 'Стеценка', '49.0'),
#  ('Оболонський', 'Героїв Сталінграда', '193.0'),
#  (None, 'Голосіївський (40-річчя Жовтня)', '41.3'),
#  (None, 'Гавела (Івана Лепсе)', '43.0'),
#  (None, 'Б. Житомирська', '350.0'),
#  (None, 'І. Павла ІІ (Патріса Лумумби)', '127.0'),
#  ('Дніпровський', 'Регенераторна', '77.9'),
#  ('Голосіївський, Печерський', 'Ковпака', '180.0'),
#  (None, 'Бойчука (Кіквідзе)', '54.54'),
#  (None, 'Максимовича (Онуфрія Трутенко)', '0.0'),
#  (None, 'Курбаса (50-річчя Жовтня)', '60.0'),
#  ('Оболонський', 'Героїв Сталінграда', '60.0'),
#  ('Подільський, Оболонський', 'Вишгородська', '174.0'),
#  ('Дарницький', 'Урлівська', '73.0'),
#  ('Шевченківський', 'Дегтярівська', '93.0'),
#  ('Дніпровський, Дарницький', 'Харківське', '73.2'),
#  ('Дарницький', 'Урлівська', '140.0'),
#  (None, 'Перемоги (Брест-Литовський)', '50.0'),
#  ('Голосіївський', 'Ломоносова', '88.0'),
#  (None, 'Заболотного', '47.8'),
#  (None, 'Маккейна (Івана Кудрі)', '43.0'),
#  ('Дарницький', 'Толстого', '72.0'),
#  ("Солом'янський", "Солом'янська", '247.0'),
#  ("Солом'янський", "Солом'янська", '247.0'),
#  ('Оболонський', 'Героїв Сталінграда', '250.0'),
#  ('Дніпровський', 'Каховська', '67.0'),
#  ('Голосіївський', 'Теремківська', '81.0'),
#  ('Дніпровський', 'Микільсько-Слобідська', '33.0'),
#  (None, 'Тимошенко', '58.3'),
#  ('Дарницький', 'Зарічна', '93.0'),
#  (None, 'Закревського', '109.0'),
#  (None, 'Конєва', '70.05'),
#  (None, 'Туполєва', '55.0'),
#  (None, 'Сверстюка (Марини Раскової)', '88.0'),
#  (None, 'Соборності (Поєднання)', '44.2'),
#  (None, 'Гедройця (Тверська)', '150.0'),
#  (None, 'Сверстюка (Марини Раскової)', '87.0'),
#  ('Печерський, Голосіївський, Шевченківський', 'Жилянська', '275.0'),
#  ('Святошинський', 'Кольцова', '80.0'),
#  ('Дарницький', 'Драгоманова', '54.0'),
#  (None, 'Перемоги (Брест-Литовський)', '43.0'),
#  ('Дарницький', 'Драгоманова', '94.0'),
#  (None, 'Маккейна (Івана Кудрі)', '42.0'),
#  ('Голосіївський, Печерський ', 'Наддніпрянське', '33.8'),
#  ('Дарницький', 'Урлівська', '116.0'),
#  ("Солом'янський", 'Богданівська', '76.0'),
#  ('Святошинський', 'Зодчих', '59.0'),
#  ('Шевченківський', 'Тургенєвська', '200.0'),
#  ('Шевченківський', 'Герцена', '70.0'),
#  ('Шевченківський', 'Герцена', '70.0'),
#  ('Шевченківський', 'Герцена', '70.0'),
#  (None, 'Руденко', '75.5'),
#  (None, 'Грушевського', '150.0'),
#  (None, 'Миколи Голого (Лебедєва-Кумача)', '162.0'),
#  (None, 'Омельяновича-Павленка (Суворова)', '45.0'),
#  ('Подільський', 'Північно-Сирецька', '62.0'),
#  (None, 'Б. Житомирська', '75.0'),
#  (None, 'Українки', '90.4'),
#  (None, 'Тютюнника (Анрі Барбюса)', '70.0'),
#  (None, 'Данченко', '95.0'),
#  ('Голосіївський, Печерський', 'Ковпака', '555.0'),
#  (None, 'Радченко', '37.62'),
#  (None, 'Лебедєва', '93.0'),
#  (None, 'Драгомирова', '55.0'),
#  (None, 'Драгомирова', '102.0'),
#  ('Подільський', 'Набережно-Рибальська', '94.0'),
#  (None, 'Сергія Колоса (Леніна)', '41.0'),
#  ('Дарницький', 'Причальна', '77.5'),
#  (None, 'Перемоги (Брест-Литовський)', '87.98'),
#  ('Дніпровський', 'Визволителів', '65.91'),
#  (None, 'Сверстюка (Марини Раскової)', '67.0'),
#  ('Подільський', 'Набережно-Рибальська', '127.24'),
#  (None, 'Порика', '31.0'),
#  (None, 'Гречка', '87.0'),
#  ('Дарницький', 'Зарічна', '82.0'),
#  (None, 'Бажана', '50.0'),
#  (None, 'Радченко', '40.0'),
#  ('Шевченківський', 'Михайлівська', '70.0'),
#  ('Шевченківський', 'Михайлівська', '70.0'),
#  ('Голосіївський', 'Ломоносова', '75.0'),
#  (None, 'Щербаківського (Щербакова)', '96.0'),
#  (None, 'Симоненко', '56.0'),
#  ('Оболонський', 'Дніпровська', '43.0'),
#  (None, 'Драгомирова', '119.0'),
#  ('Подільський', 'Андріївська', '43.0'),
#  ('Подільський', 'Копилівська', '22.0'),
#  ('Дарницький', 'Урлівська', '105.0'),
#  ("Солом'янський", 'Єреванська', '44.0'),
#  ('Дарницький', 'Драгоманова', '69.0'),
#  (None, 'ЖК Stanford', '45.0'),
#  ('Подільський', 'Правди', '95.0'),
#  (None, 'Комарова', '28.0'),
#  ('Подільський', 'Правди', '40.0'),
#  ('Дарницький', 'Толстого', '161.0'),
#  ('Дніпровський, Дарницький', 'Харківське', '100.0'),
#  (None, 'ЖК Лебединий', '65.0'),
#  ('Шевченківський', 'Паторжинського', '213.0'),
#  ("Шевченківський, Солом'янський", 'Повітрофлотський', '62.0'),
#  ('Подільський', 'Правди', '63.0'),
#  (None, 'Алмазова (Кутузова)', '90.0'),
#  (None, 'ЖК 52 Перлина (Pechersk Plaza)', '39.0'),
#  (None, 'Малиновського', '73.0'),
#  ('Дніпровський', 'Райдужна', '34.0'),
#  (None, 'Маланюка (Степана Сагайдака)', '50.0'),
#  (None, 'Дінця', '39.0'),
#  (None, 'Федорова', '55.0'),
#  ('Дарницький', 'Срібнокільська', '58.0'),
#  (None, 'ЖК Nordica Residence', '52.0'),
#  (None, 'Липківського (Урицького)', '92.0'),
#  (None, 'Дінця', '68.0'),
#  (None, 'Маланюка (Степана Сагайдака)', '84.7'),
#  (None, 'Перемоги (Брест-Литовський)', '65.0'),
#  (None, 'Парково-Сирецька (Шамрило Тимофія)', '145.0'),
#  ('Голосіївський', 'Ломоносова', '58.0'),
#  ('Деснянський', 'Маяковського', '76.0'),
#  ('Шевченківський', 'Багговутівська', '46.0'),
#  ('Дніпровський', 'Дарницький', '88.0'),
#  (None, 'Чавдар', '93.3'),
#  ('Голосіївський, Печерський ', 'Наддніпрянське', '41.6'),
#  ('Оболонський', 'Героїв Сталінграда', '58.0'),
#  ('Подільський', 'Правди', '52.0'),
#  (None, 'Конєва', '70.0'),
#  ('Дніпровський', 'Воскресенська', '65.0'),
#  ('Печерський', 'Саперне Поле', '47.0'),
#  ('Голосіївський', 'Ясинуватський', '79.0'),
#  (None, 'Потапова', '34.0'),
#  (None, 'Кондратюка', '98.0'),
#  (None, 'Чаадаєва', '50.0'),
#  (None, 'Пчілки', '70.0'),
#  (None, 'Гречка', '45.0'),
#  ('Печерський', 'Саперне Поле', '150.0'),
#  ('Шевченківський', 'Глибочицька', '66.0'),
#  ('Дарницький', 'Причальна', '65.0'),
#  (None, 'Болсунівська (Сергія Струтинського)', '130.0'),
#  (None, 'Сікорського (Танкова)', '70.0'),
#  ('Голосіївський', 'Костанайська', '60.0'),
#  ('Оболонський', 'Богатирська', '78.0'),
#  ('Дарницький', 'Малоземельна', '53.0'),
#  ('Подільський', 'Спаська', '65.0'),
#  ('Святошинський', 'Прорізна', '87.3'),
#  ('Шевченківський', 'Прорізна', '87.3'),
#  ('Деснянський', 'Милославська', '69.0'),
#  (None, 'ЖК Бульвар Фонтанів', '61.0'),
#  (None, 'Драгомирова', '81.0'),
#  (None, 'Гавела (Івана Лепсе)', '57.0'),
#  (None, 'Данченко', '48.0'),
#  (None, 'Шолуденко', '47.0'),
#  ('Шевченківський', 'Михайлівський', '93.0'),
#  (None, 'ЖК CRYSTAL RESIDENCE', '49.0'),
#  (None, 'Бойчука (Кіквідзе)', '66.25'),
#  (None, 'Антоновича (Горького)', '72.0'),
#  ('Шевченківський', 'Ольжича', '65.0'),
#  ('Дарницький', 'Ревуцького', '49.0'),
#  (None, 'ЖК Берег Дніпра', '31.0'),
#  ("Солом'янський", 'Практична', '41.0'),
#  (None, 'Жмаченко', '53.0'),
#  (None, 'Скрипника (Микола Островського)', '77.0'),
#  (None, 'Коновальця (Щорса)', '100.0'),
#  (None, 'Бажана', '55.0'),
#  (None, 'Григоренко', '58.0'),
#  (None, 'ЖК Manhattan city', '52.0'),
#  (None, 'Драгомирова', '312.0'),
#  (None, 'Данченко', '87.0'),
#  (None, 'Бутишев (Андрія Іванова)', '145.0'),
#  (None, 'Маккейна (Івана Кудрі)', '50.0'),
#  ('Печерський', 'Лейпцизька', '125.0'),
#  ('Подільський', 'Правди', '43.0'),
#  (None, 'Болсунівська (Сергія Струтинського)', '130.0'),
#  (None, 'Драгомирова', '81.0'),
#  ('Печерський', 'Старонаводницька', '208.0'),
#  ("Солом'янський", 'Протасів Яр', '306.0'),
#  ('Оболонський', 'Дніпровська', '54.0'),
#  (None, 'Лобановського (Червонозоряний)', '105.0'),
#  ('Оболонський', 'Дніпровська', '69.0'),
#  ('Шевченківський', 'Павлівська', '66.0'),
#  ('Голосіївський', 'Ломоносова', '67.0'),
#  (None, 'Ахматової', '46.0'),
#  (None, 'Вернадського', '104.0'),
#  ('Оболонський', 'Балтійський', '55.0'),
#  (None, 'Липківського (Урицького)', '92.0'),
#  (None, 'Резницька', '86.0'),
#  ('Дніпровський', 'Каховська', '87.0'),
#  (None, 'Закревського', '43.2'),
#  (None, 'Сверстюка (Марини Раскової)', '86.74'),
#  ('Подільський', 'Правди', '90.77'),
#  ('Оболонський', 'Героїв Сталінграда', '48.6'),
#  ('Подільський', 'Правди', '86.38'),
#  ('Оболонський', 'Героїв Дніпра', '51.0'),
#  (None, 'Б. Житомирська', '250.0'),
#  (None, 'Корольова', '25.0'),
#  (None, 'Крушельницької', '42.0'),
#  ('Дніпровський', 'Регенераторна', '46.0'),
#  ('Голосіївський', 'Голосіївська', '127.0'),
#  ('Голосіївський', 'Голосіївська', '127.0'),
#  (None, 'Старокиївська', '46.0'),
#  ('Оболонський', 'Дніпровська', '66.0'),
#  ('Оболонський', 'Героїв Сталінграда', '122.8'),
#  (None, 'Сікорського (Танкова)', '70.0'),
#  ('Голосіївський, Печерський, Шевченківський', 'Саксаганського', '81.0'),
#  ('Дарницький', 'Драгоманова', '54.9'),
#  ('Оболонський', 'Героїв Дніпра', '41.3'),
#  (None, 'Велика Васильківська (Червоноармійська)', '85.0'),
#  (None, 'Малевича (Василя Боженка)', '79.0'),
#  ('Подільський', 'Юрківська', '83.0'),
#  ('Шевченківський', 'Нагірна', '38.0'),
#  ('Подільський', 'Щекавицька', '160.0'),
#  ('Подільський', 'Щекавицька', '160.0'),
#  (None, 'Жуковського', '37.0'),
#  ('Шевченківський', 'Павлівська', '198.3'),
#  (None, 'Маккейна (Івана Кудрі)', '108.0'),
#  (None, 'Бальзака', '150.0'),
#  ('Дарницький', 'Приозерна', '72.0'),
#  ('Оболонський', 'Приозерна', '72.0'),
#  ('Печерський', 'Інститутська', '130.9'),
#  ('Подільський', 'Правди', '41.0'),
#  (None, 'Коновальця (Щорса)', '53.0'),
#  ('Дарницький', 'Зарічна', '43.0'),
#  (None, 'Стражеска', '46.5'),
#  ('Дніпровський, Дарницький', 'Харківське', '71.0'),
#  ('Печерський, Голосіївський, Шевченківський', 'Жилянська', '56.0'),
#  ('Дарницький', 'Бориспільська', '118.0'),
#  ('Дніпровський', 'Воскресенська', '80.0'),
#  (None, 'Дігтярна', '85.0'),
#  (None, "Сім'ї Прахових (Гайдара)", '104.0'),
#  ('Оболонський', 'Богатирська', '60.27'),
#  (None, 'Мурашка', '47.3'),
#  ('Шевченківський', 'Щусєва', '31.0'),
#  ('Шевченківський', 'Щусєва', '31.0'),
#  (None, 'Андрющенко', '90.0'),
#  (None, 'Ділова (Георгія Димитрова)', '104.0'),
#  (None, 'Перемоги (Брест-Литовський)', '46.0'),
#  (None, 'Маккейна (Івана Кудрі)', '103.0'),
#  (None, 'Драйзера', '38.0'),
#  ('Дарницький', 'Срібнокільська', '111.0'),
#  (None, 'Туманяна', '90.0'),
#  (None, 'Відрадний (Чубаря)', '55.8'),
#  ('Оболонський', 'Попова', '79.0'),
#  ('Оболонський', 'Попова', '79.0'),
#  ('Дніпровський', 'Зелена', '74.0'),
#  ("Солом'янський", 'Зелена', '74.0'),
#  ('Шевченківський', 'Зелена', '74.0'),
#  (None, 'Курчатова', '46.0'),
#  (None, 'Архипенко (Залки Мате)', '49.0'),
#  ('Дарницький', 'Здолбунівська', '76.0'),
#  ('Деснянський', 'Градинська', '103.0'),
#  ('Оболонський', 'Дніпровська', '46.5'),
#  ('Голосіївський', 'Теремківська', '110.0'),
#  (None, 'Українки', '70.0'),
#  ("Солом'янський", 'Ушинського', '95.09'),
#  ("Солом'янський", 'Ушинського', '95.09'),
#  ('Подільський', 'Бондарський', '60.0'),
#  ('Деснянський', 'Милославська', '93.0'),
#  ('Оболонський', 'Героїв Сталінграда', '130.0'),
#  ("Солом'янський", 'Практична', '25.0'),
#  ('Шевченківський', 'Герцена', '55.0'),
#  ('Шевченківський', 'Герцена', '55.0'),
#  ('Шевченківський', 'Герцена', '55.0'),
#  ('Шевченківський', 'Тургенєвська', '171.0'),
#  ('Деснянський', 'Магнітогорська', '43.0'),
#  ('Оболонський', 'Героїв Сталінграда', '48.0'),
#  ('Шевченківський', 'Полтавська', '87.0'),
#  (None, 'Перемоги (Брест-Литовський)', '53.0'),
#  (None, 'Річкова', '84.0'),
#  ('Подільський', 'Ярославська', '46.0'),
#  ('Голосіївський', 'Деміївська', '52.0'),
#  ('Голосіївський', 'Деміївська', '52.0'),
#  ('Печерський', 'Саперне Поле', '91.0'),
#  ('Дніпровський', 'Каховська', '65.0'),
#  (None, 'Бойчука (Кіквідзе)', '82.0'),
#  ('Печерський, Шевченківський', 'Хрещатик', '88.0'),
#  (None, 'Червоноткацька', '41.0'),
#  (None, 'Грушевського', '150.0'),
#  ('Дарницький', 'Драгоманова', '73.0'),
#  ('Дніпровський', 'Каховська', '81.0'),
#  (None, 'Антоновича (Горького)', '50.0'),
#  (None, 'Максимовича (Онуфрія Трутенко)', '37.0'),
#  (None, 'Драгомирова', '60.0'),
#  (None, 'ЖК POLARIS Home&Plaza', '30.0'),
#  (None, 'Комфортна та сучасна', '63.0'),
#  ('Шевченківський', 'Паторжинського', '213.0'),
#  (None, 'Голосіївський (40-річчя Жовтня)', '73.7'),
#  ('Дніпровський, Дарницький', 'Харківське', '45.1'),
#  (None, 'Йорданська (Гавро Лайоша)', '87.0'),
#  (None, 'ЖК Ярославів Град', '68.0'),
#  (None, 'Вільямса', '103.0'),
#  (None, 'Жмаченко', '79.97'),
#  (None, 'Радченко', '91.0'),
#  ('Голосіївський', 'Ясинуватський', '64.0'),
#  (None, 'ЖК Бульвар Фонтанів', '61.0'),
#  ('Подільський, Оболонський', 'Вишгородська', '94.0'),
#  ('Подільський, Оболонський', 'Вишгородська', '111.0'),
#  ('Шевченківський', 'Герцена', '46.0'),
#  ('Шевченківський', 'Герцена', '46.0'),
#  ('Шевченківський', 'Герцена', '46.0'),
#  ('Печерський', 'Предславинська', '40.0'),
#  (None, 'Вербицького', '70.0'),
#  ('Голосіївський', 'Тарасівська', '84.0'),
#  (None, 'ЖК Olympic Park', '53.0'),
#  (None, 'Липківського (Урицького)', '80.0'),
#  (None, 'Кирилівська (Фрунзе)', '70.0'),
#  ('Святошинський', 'Маршака', '137.0'),
#  ('Святошинський', 'Маршака', '137.0'),
#  ('Святошинський', 'Берковецька', '51.0'),
#  ('Дарницький', 'Драгоманова', '52.0'),
#  (None, 'Хмельницького', '248.0'),
#  ('Дарницький', 'Драгоманова', '52.0'),
#  (None, 'Сверстюка (Марини Раскової)', '74.0'),
#  ('Подільський', 'Лисянська', '108.0'),
#  (None, 'Антоновича (Горького)', '111.1'),
#  (None, 'Максимовича (Онуфрія Трутенко)', '123.89'),
#  ('Оболонський', 'Дніпровська', '55.0'),
#  ('Голосіївський', 'Васильківська', '67.0'),
#  (None, 'Панельна', '70.0'),
#  (None, 'Драгомирова', '88.0'),
#  (None, 'Виборзька', '24.0'),
#  (None, 'Гулака', '42.8'),
#  (None, 'Маланюка (Степана Сагайдака)', '96.19'),
#  (None, 'Антоновича (Горького)', '46.0'),
#  (None, 'Болсунівська (Сергія Струтинського)', '250.0'),
#  ('Дніпровський', 'Каховська', '37.0'),
#  ('Дарницький', 'Осокорська', '51.0'),
#  (None, 'Липківського (Урицького)', '61.0'),
#  ('Дарницький', 'Срібнокільська', '110.0'),
#  (None, 'Гавела (Івана Лепсе)', '64.0'),
#  (None, 'Теліги', '32.1'),
#  (None, 'Ахматової', '110.0'),
#  (None, 'Перемоги (Брест-Литовський)', '51.0'),
#  ('Голосіївський, Печерський, Шевченківський', 'Саксаганського', '70.0'),
#  (None, 'Українки', '45.0'),
#  ('Деснянський', 'Радистів', '74.2'),
#  ('Деснянський', 'Радистів', '74.2'),
#  ('Деснянський', 'Радистів', '74.2'),
#  ('Шевченківський', 'Лисенка', '70.0'),
#  (None, 'Максимовича (Онуфрія Трутенко)', '41.08'),
#  (None, 'Перемоги (Брест-Литовський)', '80.0'),
#  ('Оболонський', 'Дніпровська', '40.0'),
#  (None, 'Коновальця (Щорса)', '54.0'),
#  ('Оболонський', 'Дніпровська', '98.0'),
#  ('Шевченківський', 'Золотоустівська', '185.0'),
#  ('Подільський', 'Північно-Сирецька', '48.75'),
#  (None, 'Дяченка', '73.0'),
#  (None, 'Драгомирова', '110.0'),
#  ('Дніпровський', 'Лобачевського', '40.0'),
#  ('Дніпровський', 'Лобачевського', '40.0'),
#  ('Дарницький', 'Толстого', '165.0'),
#  (None, 'Вербицького', '74.0'),
#  (None, 'І. Павла ІІ (Патріса Лумумби)', '57.0'),
#  ('Оболонський', 'Бережанська', '70.0'),
#  (None, 'Сверстюка (Марини Раскової)', '86.72'),
#  ('Оболонський', 'Героїв Сталінграда', '78.0'),
#  (None, 'Перемоги (Брест-Литовський)', '58.7'),
#  ('Святошинський', 'Львівська', '92.0'),
#  ('Шевченківський', 'Львівська', '92.0'),
#  ('Дарницький', 'Драгоманова', '54.0'),
#  (None, 'Перемоги (Брест-Литовський)', '85.0'),
#  ('Дарницький', 'Здолбунівська', '350.0'),
#  (None, 'Перемоги (Брест-Литовський)', '80.1'),
#  (None, 'Антоновича (Горького)', '170.0'),
#  (None, 'Українки', '48.0'),
#  (None, 'Наумова', '55.0'),
#  (None, 'Богомольця', '230.0'),
#  (None, 'Бойчука (Кіквідзе)', '155.72'),
#  (None, 'Бойчука (Кіквідзе)', '81.6'),
#  ('Голосіївський', 'Голосіївська', '91.2'),
#  ('Голосіївський', 'Голосіївська', '91.2'),
#  (None, 'Малевича (Василя Боженка)', '120.3'),
#  (None, "Сім'ї Ідзіковських (Михайло Мішина)", '29.0'),
#  ('Голосіївський, Шевченківський', 'Володимирська', '67.0'),
#  ('Оболонський', 'Балтійський', '72.0'),
#  ('Голосіївський', 'Феодосійська', '55.0'),
#  (None, 'Кібальчича', '47.24'),
#  ('Дарницький', 'Ревуцького', '49.31'),
#  ('Печерський', 'Предславинська', '62.0'),
#  (None, 'Коновальця (Щорса)', '130.0'),
#  (None, 'Антоновича (Горького)', '67.0'),
#  ("Солом'янський", 'Машинобудівний', '42.0'),
#  (None, 'Гаврилишина (Ванди Василевської)', '74.0'),
#  ('Дніпровський, Дарницький', 'Харківське', '88.0'),
#  ('Голосіївський', 'Ломоносова', '49.0'),
#  (None, 'Сверстюка (Марини Раскової)', '42.0'),
#  (None, 'Гонгадзе (Машинобудівна)', '49.0'),
#  ("Шевченківський, Солом'янський", 'Повітрофлотський', '55.0'),
#  (None, 'Маккейна (Івана Кудрі)', '42.0'),
#  ('Печерський', 'Старонаводницька', '142.0'),
#  ("Солом'янський", 'Практична', '50.0'),
#  ('Оболонський', 'Оболонський', '32.0'),
#  ('Дарницький', 'Причальна', '44.0'),
#  ('Голосіївський', 'Микільсько-Ботанічна', '52.0'),
#  (None, 'Бойчука (Кіквідзе)', '156.0'),
#  ('Шевченківський', 'Глибочицька', '123.0'),
#  (None, 'Драгомирова', '165.0'),
#  ('Шевченківський', 'Глибочицька', '66.0'),
#  (None, 'Велика Васильківська (Червоноармійська)', '82.2'),
#  (None, 'Тимошенко', '41.0'),
#  ('Дніпровський', 'Ентузіастів', '42.0'),
#  (None, 'Іпсілантіївський (Аїстова)', '61.0'),
#  (None, 'Туманяна', '80.0'),
#  (None, 'Драгомирова', '119.0'),
#  (None, 'Чорновола (Косіора)', '53.0'),
#  (None, 'Болсунівська (Сергія Струтинського)', '63.0'),
#  (None, 'Підвисоцького', '43.0'),
#  ('Оболонський', 'Оболонський', '86.0'),
#  (None, 'Драгомирова', '120.0'),
#  (None, 'Котельникова', '108.0'),
#  ("Солом'янський", 'Нижньоключова', '94.0'),
#  ('Оболонський', 'Дніпровська', '115.0'),
#  (None, 'Радченко', '36.25'),
#  ('Шевченківський', 'Ясногірська', '55.0'),
#  ('Дніпровський', 'Каховська', '62.0'),
#  (None, 'ЖК Washington Concept House', '53.0'),
#  ('Подільський', 'Дмитрівська', '48.5'),
#  ('Шевченківський', 'Дмитрівська', '48.5'),
#  (None, 'Оболонська набережна', '122.0'),
#  (None, 'Чорновола (Косіора)', '90.0'),
#  (None, 'Дружби народів', '55.0'),
#  ('Голосіївський', 'Метрологічна', '40.0'),
#  (None, 'ЖК Forward', '46.0'),
#  (None, 'Коновальця (Щорса)', '340.0'),
#  ('Голосіївський, Печерський ', 'Наддніпрянське', '41.0'),
#  (None, 'Микільський (Січневий)', '47.0'),
#  (None, 'Коласа', '55.0'),
#  (None, 'ЖК Dibrova Park', '79.0'),
#  (None, 'Вернадського', '65.0'),
#  (None, 'Калнишевського (Михайло Майорова)', '32.0'),
#  ("Шевченківський, Солом'янський", 'Повітрофлотський', '63.0'),
#  ('Дніпровський', 'Микільсько-Слобідська', '50.0'),
#  (None, 'Перемоги (Брест-Литовський)', '36.0'),
#  ('Дарницький', 'Березнева', '35.0'),
#  ('Дніпровський', 'Березнева', '35.0'),
#  (None, 'ЖК Krauss Gallery', '52.0'),
#  (None, 'Пчілки', '50.0'),
#  ('Оболонський', 'Героїв Сталінграда', '165.0'),
#  (None, 'Перемоги (Брест-Литовський)', '71.0'),
#  ('Голосіївський', 'Ломоносова', '110.0'),
#  ("Солом'янський", 'Протасів Яр', '102.0'),
#  ("Солом'янський", 'Нижньоключова', '80.0'),
#  ('Святошинський', 'Кулібіна', '60.0'),
#  ('Святошинський', 'Кулібіна', '60.0'),
#  (None, 'Пчілки', '70.0'),
#  (None, 'Симиренко', '80.0'),
#  ('Дніпровський', 'Регенераторна', '84.0'),
#  (None, 'Ахматової', '72.0'),
#  (None, 'Коновальця (Щорса)', '96.0'),
#  (None, 'Віфлеємська (Академіка Шліхтера)', '32.0'),
#  (None, 'Гмирі', '113.0'),
#  ('Голосіївський', 'Голосіївська', '119.0'),
#  ('Голосіївський', 'Голосіївська', '119.0'),
#  (None, 'Вернадського', '61.0'),
#  (None, 'Соборності (Поєднання)', '75.0'),
#  (None, 'Антоновича (Горького)', '54.83'),
#  ('Дніпровський', 'Регенераторна', '82.0'),
#  (None, 'Калнишевського (Михайло Майорова)', '98.0'),
#  ('Подільський, Шевченківський', 'Стеценка', '32.0'),
#  ('Святошинський', 'Кольцова', '37.0'),
#  (None, 'Палладіна', '96.0'),
#  (None, 'Тютюнника (Анрі Барбюса)', '74.0'),
#  ('Святошинський', 'Львівська', '54.0'),
#  ('Шевченківський', 'Львівська', '54.0'),
#  (None, "Мар'яненко", '88.0'),
#  ('Подільський, Оболонський', 'Вишгородська', '125.2'),
#  ('Оболонський', 'Дніпровська', '65.0'),
#  (None, 'Андріївський', '50.0'),
#  ('Дарницький', 'Урлівська', '100.0'),
#  (None, 'Гавела (Івана Лепсе)', '125.0'),
#  ('Оболонський', 'Балтійський', '55.0'),
#  ('Шевченківський', 'Багговутівська', '55.0'),
#  (None, 'ЖК CRYSTAL RESIDENCE', '49.0'),
#  ('Оболонський', 'Балтійський', '51.89'),
#  (None, 'Воробйова (Курська)', '55.0'),
#  (None, 'Гончара', '60.4'),
#  ('Печерський', 'Лейпцизька', '130.0'),
#  (None, 'Тираспільська', '40.0'),
#  (None, 'ЖК Diadans', '56.0'),
#  ('Дніпровський', 'Краківська', '75.0'),
#  (None, 'Сабурова', '98.0'),
#  ('Шевченківський', 'Глибочицька', '58.4'),
#  ('Оболонський', 'Героїв Сталінграда', '51.0'),
#  (None, 'ЖК Chalet', '32.0'),
#  (None, 'Івана Мазепи (Січневого повстання)', '308.0'),
#  (None, 'Радченко', '30.0'),
#  (None, 'Алмазова (Кутузова)', '90.0'),
#  (None, 'Городецького', '61.0'),
#  (None, 'Маланюка (Степана Сагайдака)', '105.0'),
#  ('Дніпровський', 'Каховська', '32.0'),
#  (None, 'ЖК Svitlo Park', '27.0'),
#  ('Дарницький', 'Вишняківська', '37.0'),
#  ('Деснянський, Дніпровський', 'Миропільська', '76.0'),
#  ('Голосіївський', 'Феодосійська', '75.0'),
#  (None, 'Малевича (Василя Боженка)', '65.0'),
#  (None, 'Тютюнника (Анрі Барбюса)', '114.0'),
#  (None, 'Коновальця (Щорса)', '152.0'),
#  ('Оболонський', 'Дніпровська', '115.0'),
#  (None, 'Маланюка (Степана Сагайдака)', '89.0'),
#  ('Печерський, Голосіївський, Шевченківський', 'Жилянська', '70.0'),
#  ('Оболонський', 'Оболонський', '84.2'),
#  ('Шевченківський', 'Павлівська', '157.6'),
#  ('Печерський', 'Крутий', '85.0'),
#  ('Святошинський', 'Берковецька', '83.0'),
#  (None, 'Оболонська набережна', '119.0'),
#  ('Дарницький', 'Зарічна', '100.0'),
#  ('Святошинський', 'Юнацька', '42.0'),
#  ("Солом'янський", 'Юнацька', '42.0'),
#  ('Подільський', 'Правди', '44.0'),
#  (None, 'Драгомирова', '262.0'),
#  (None, 'Драгомирова', '125.0'),
#  ('Деснянський', 'Крайня', '35.0'),
#  ('Дніпровський, Дарницький', 'Харківське', '51.0'),
#  ('Подільський', 'Правди', '66.0'),
#  (None, 'Перемоги (Брест-Литовський)', '68.0'),
#  ('Деснянський, Дніпровський', 'Братиславська', '70.0'),
#  (None, 'Краснопільська', '113.0'),
#  (None, 'Гавела (Івана Лепсе)', '66.2'),
#  (None, 'Тютюнника (Анрі Барбюса)', '108.0'),
#  ('Подільський', 'Північно-Сирецька', '46.0'),
#  ('Солом’янський', 'Гарматна', '60.0'),
#  (None, 'Гавела (Івана Лепсе)', '125.0'),
#  ('Оболонський', 'Героїв Сталінграда', '58.0'),
#  (None, 'Бойчука (Кіквідзе)', '198.5'),
#  (None, 'Кривоноса', '120.0'),
#  (None, 'ЖК Ярославів Град', '68.0'),
#  ('Дарницький', 'Бориспільська', '42.0'),
#  ('Дарницький', 'Ревуцького', '69.0'),
#  (None, 'Маккейна (Івана Кудрі)', '86.0'),
#  (None, 'Радченко', '32.0'),
#  (None, 'Чаадаєва', '144.3'),
#  (None, 'ЖК Manhattan city', '52.0'),
#  (None, 'Липківського (Урицького)', '92.0'),
#  ('Святошинський', 'Клавдіївська', '60.0'),
#  (None, 'Заболотного', '81.09'),
#  ('Голосіївський', 'Ломоносова', '189.0'),
#  (None, 'ЖК Володимирський', '59.0'),
#  ('Оболонський', 'Дніпровська', '69.0'),
#  ('Дарницький', 'Поліська', '48.0'),
#  ("Солом'янський", 'Іскрівська', '62.0'),
#  ('Шевченківський', 'Ризька', '87.0'),
#  ('Подільський', 'Правди', '83.0'),
#  (None, 'Антоновича (Горького)', '65.0'),
#  (None, 'Житловий район', '37.0'),
#  ('Шевченківський', 'Салютна', '56.0'),
#  (None, 'Омельяновича-Павленка (Суворова)', '64.0'),
#  (None, 'Стуса', '78.0'),
#  (None, 'Українки', '64.0'),
#  ('Дарницький', 'Вишняківська', '37.0'),
#  (None, 'Тютюнника (Анрі Барбюса)', '117.0'),
#  ('Печерський', 'Виноградний', '45.0'),
#  (None, 'Перемоги (Брест-Литовський)', '42.0'),
#  ('Оболонський', 'Дніпровська', '115.0'),
#  (None, 'Перемоги (Брест-Литовський)', '52.1'),
#  (None, 'Туполєва', '76.0'),
#  ('Печерський', 'Старонаводницька', '115.0'),
#  ('Оболонський', 'Балтійський', '40.22'),
#  (None, 'Бойчука (Кіквідзе)', '59.62'),
#  ('Печерський', 'Бастіонна', '44.0'),
#  ('Дарницький', 'Ревуцького', '90.0'),
#  (None, 'Болсунівська (Сергія Струтинського)', '68.0'),
#  ("Шевченківський, Солом'янський", 'Повітрофлотський', '46.22'),
#  ('Шевченківський', 'Золотоустівська', '106.2'),
#  (None, 'Русовий', '85.0'),
#  ('Голосіївський, Печерський, Шевченківський', 'Саксаганського', '130.0'),
#  ('Голосіївський', 'Теремківська', '45.0'),
#  (None, 'Кібальчича', '46.0'),
#  (None, 'Радченко', '40.95'),
#  (None, 'Голосіївський (40-річчя Жовтня)', '112.0'),
#  ('Голосіївський', 'Лисогірський', '55.2'),
#  ('Шевченківський', 'Гоголівська', '86.2'),
#  (None, 'Тютюнника (Анрі Барбюса)', '55.0'),
#  ("Солом'янський", "Солом'янська", '41.0'),
#  ("Солом'янський", "Солом'янська", '41.0'),
#  ('Оболонський', 'Героїв Сталінграда', '75.0'),
#  ('Шевченківський', 'Глибочицька', '125.0'),
#  ('Печерський, Голосіївський, Шевченківський', 'Жилянська', '124.14'),
#  (None, 'Доброхотова', '78.9'),
#  ('Печерський, Голосіївський, Шевченківський', 'Жилянська', '158.0'),
#  (None, 'Відрадний (Чубаря)', '44.0'),
#  ('Печерський', 'Предславинська', '48.0'),
#  (None, 'Іпсілантіївський (Аїстова)', '61.0'),
#  ('Шевченківський', 'Глибочицька', '66.0'),
#  (None, 'Голосіївський (40-річчя Жовтня)', '133.0'),
#  ('Оболонський', 'Оболонський', '47.0'),
#  ('Шевченківський', 'Багговутівська', '135.0'),
#  ('Подільський', 'Правди', '35.0'),
#  ('Дарницький', 'Причальна', '44.0'),
#  (None, 'Бойчука (Кіквідзе)', '64.8'),
#  ('Деснянський', 'Радистів', '41.0'),
#  ('Деснянський', 'Радистів', '41.0'),
#  ('Деснянський', 'Радистів', '41.0'),
#  ('Шевченківський', "Лук'янівська", '51.0'),
#  ('Шевченківський', "Лук'янівська", '51.0'),
#  ('Подільський', 'Правди', '55.0'),
#  (None, 'Шевельова (Микола Руднєва)', '81.0'),
#  ('Оболонський', 'Героїв Сталінграда', '82.0'),
#  (None, 'Єфремова (Уборевича Командарма)', '89.0'),
#  ('Оболонський', 'Балтійський', '44.3'),
#  (None, 'Бойчука (Кіквідзе)', '44.0'),
#  (None, 'Івана Мазепи (Січневого повстання)', '358.0'),
#  (None, 'Гришко', '95.0'),
#  (None, "Сім'ї Сосніних", '68.0'),
#  ('Дніпровський, Дарницький', 'Харківське', '112.0'),
#  ('Деснянський', 'Будищанська', '38.0'),
#  (None, 'МФК Intergal City', '44.0'),
#  ('Печерський', 'Мечнікова', '72.4'),
#  ('Оболонський', 'Дніпровська', '40.0'),
#  ('Деснянський', 'Маяковського', '70.0'),
#  (None, 'Гончара', '57.51'),
#  (None, 'І. Павла ІІ (Патріса Лумумби)', '63.0'),
#  (None, 'ЖК Rusaniv Residence', '42.0'),
#  ('Оболонський', 'Героїв Сталінграда', '120.0'),
#  (None, 'Драгомирова', '120.0'),
#  (None, 'Драгомирова', '70.0'),
#  ('Оболонський', 'Героїв Сталінграда', '160.0'),
#  (None, 'ЖК Olympic Park', '53.0'),
#  (None, 'Драгомирова', '222.0'),
#  ('Шевченківський', 'Бессарабська', '104.0'),
#  ('Голосіївський', 'Ломоносова', '44.0'),
#  (None, 'Тираспільська', '47.0'),
#  (None, 'Франка', '200.3'),
#  ('Печерський', 'Шовковична', '72.0'),
#  (None, 'ЖК Берег Дніпра', '31.0'),
#  (None, 'Голосіївський (40-річчя Жовтня)', '66.0'),
#  ('Голосіївський', 'Ломоносова', '120.0'),
#  ('Оболонський', 'Героїв Сталінграда', '95.0'),
#  ('Дніпровський', 'Регенераторна', '112.0'),
#  ('Шевченківський', 'Салютна', '50.0'),
#  ('Печерський', 'Саперне Поле', '126.0')]

# %%
# створити запит для наповнення таблиці `result` результатом запиту на об'єднання
stmt_insert = "INSERT INTO result " + stmt_join
print(f"stmt_insert:\n{stmt_insert}")
# Out:
# stmt_insert:
# INSERT INTO result SELECT street_district.district, street_flat_propery.street, street_flat_propery.total_area FROM               street_flat_propery LEFT JOIN street_district ON street_flat_propery.street = street_district.street

# %%
# виконати запит на заповнення
cur.execute(stmt_insert)

# %%
# сберегти вміст створеної таблиці у вигляді списка
result_list = cur.execute("SELECT * FROM result").fetchall()

_ = [print(x) for x in result_list]

# завершимо всі транзакції
conn.commit()

# закріємо з'єднання
conn.close()
# Out:
# (None, 'Малиновського', 73.0)
# (None, "Сім'ї Сосніних", 110.27)
# (None, 'Лобановського (Червонозоряний)', 100.0)
# (None, 'Руставелі', 58.0)
# ('Голосіївський', 'Ломоносова', 79.0)
# ('Печерський', 'Інститутська', 138.7)
# (None, 'Антоновича (Горького)', 201.4)
# ('Оболонський', 'Дніпровська', 87.0)
# ('Печерський', 'Предславинська', 40.0)
# (None, 'Коперника', 51.0)
# (None, 'Драгомирова', 48.0)
# (None, 'Драгомирова', 85.0)
# ('Дарницький', 'Ревуцького', 76.0)
# ('Деснянський', 'Пожарського', 56.0)
# ('Дніпровський', 'Пожарського', 56.0)
# (None, 'Гмирі', 38.0)
# ('Дарницький', 'Приозерна', 70.0)
# ('Оболонський', 'Приозерна', 70.0)
# (None, 'Коперника', 103.0)
# ('Подільський, Шевченківський', 'Стеценка', 56.44)
# ('Деснянський', 'Каштанова', 69.0)
# ('Подільський', 'Правди', 47.39)
# ('Дарницький', 'Трускавецька', 50.0)
# (None, 'Наумова', 64.0)
# (None, 'Лобановського (Червонозоряний)', 96.0)
# ('Шевченківський', 'Салютна', 46.0)
# (None, 'Василенка', 44.0)
# (None, 'Палладіна', 100.0)
# (None, 'Міт. А. Шептицького (Анатолія Луначарського)', 240.0)
# ('Оболонський', 'Балтійський', 72.1)
# ('Оболонський', 'Дніпровська', 75.0)
# ('Печерський', 'Станіславського', 78.0)
# (None, 'Драгомирова', 126.0)
# ('Подільський', 'Правди', 93.0)
# (None, 'Максимовича (Онуфрія Трутенко)', 63.0)
# (None, 'ЖК PARKLAND', 44.0)
# ('Дарницький', 'Причальна', 67.92)
# (None, 'Перемоги (Брест-Литовський)', 52.0)
# ("Солом'янський", 'Богданівська', 99.0)
# ('Печерський', 'Тверський', 96.0)
# ('Подільський', 'Набережно-Хрещатицька', 65.0)
# (None, 'Липківського (Урицького)', 50.0)
# ('Подільський', 'Правди', 76.0)
# ('Оболонський', 'Дніпровська', 45.3)
# (None, 'Тютюнника (Анрі Барбюса)', 99.0)
# (None, '3-кімнатна квартира 74', 74.7)
# ('Подільський', 'Правди', 59.0)
# (None, 'Закревського', 73.0)
# ('Печерський', 'Тверський', 62.0)
# (None, 'Туполєва', 76.0)
# ('Шевченківський', 'Глибочицька', 76.0)
# (None, 'Січових Стрільців (Артема)', 210.0)
# ('Подільський, Оболонський', 'Вишгородська', 33.0)
# (None, 'Бойчука (Кіквідзе)', 66.8)
# ('Печерський', 'Предславинська', 62.0)
# (None, 'Вадима Гетьмана', 102.1)
# ('Дарницький', 'Драгоманова', 110.0)
# ("Солом'янський", 'Ніжинська', 51.0)
# (None, 'Кучера', 44.0)
# (None, 'Голосіївський (40-річчя Жовтня)', 91.0)
# (None, 'Іллєнко (Мельникова)', 28.0)
# (None, 'Бойчука (Кіквідзе)', 56.0)
# ('Шевченківський', 'Половецька', 67.3)
# ('Голосіївський, Шевченківський', 'Володимирська', 100.0)
# (None, 'Гончара', 82.0)
# (None, 'Антоновича (Горького)', 122.0)
# ('Голосіївський', 'Метрологічна', 45.0)
# (None, 'Калнишевського (Михайло Майорова)', 75.0)
# ('Дарницький', 'Зарічна', 34.0)
# (None, 'Тичини', 46.0)
# ('Голосіївський', 'Саперно-Слобідська', 100.0)
# (None, 'Комарова', 99.0)
# (None, 'Б. Житомирська', 75.0)
# ('Дніпровський', 'Каховська', 62.0)
# ('Шевченківський', 'Глибочицька', 76.0)
# (None, 'Січових Стрільців (Артема)', 210.0)
# ('Подільський, Оболонський', 'Вишгородська', 33.0)
# (None, 'Бойчука (Кіквідзе)', 66.8)
# ('Печерський', 'Предславинська', 62.0)
# (None, 'Вадима Гетьмана', 102.1)
# ('Дарницький', 'Драгоманова', 110.0)
# ("Солом'янський", 'Ніжинська', 51.0)
# (None, 'Кучера', 44.0)
# (None, 'Голосіївський (40-річчя Жовтня)', 91.0)
# (None, 'Іллєнко (Мельникова)', 28.0)
# (None, 'Бойчука (Кіквідзе)', 56.0)
# ('Шевченківський', 'Половецька', 67.3)
# ('Голосіївський, Шевченківський', 'Володимирська', 100.0)
# (None, 'Гончара', 82.0)
# (None, 'Антоновича (Горького)', 122.0)
# ('Голосіївський', 'Метрологічна', 45.0)
# (None, 'Калнишевського (Михайло Майорова)', 75.0)
# ('Дарницький', 'Зарічна', 34.0)
# (None, 'Тичини', 46.0)
# ('Голосіївський', 'Саперно-Слобідська', 100.0)
# (None, 'Комарова', 99.0)
# (None, 'Б. Житомирська', 75.0)
# ('Дніпровський', 'Каховська', 62.0)
# ('Оболонський', 'Оболонська', 72.0)
# ('Оболонський', 'Оболонська', 72.0)
# ('Подільський', 'Оболонська', 72.0)
# (None, 'Червоноткацька', 116.3)
# (None, 'Драгомирова', 159.0)
# ('Оболонський', 'Автозаводська', 76.0)
# (None, 'Тираспільська', 47.32)
# (None, 'Щербаківського (Щербакова)', 44.0)
# ('Подільський', 'Правди', 95.0)
# (None, 'Голосіївський (40-річчя Жовтня)', 240.0)
# (None, 'Максимовича (Онуфрія Трутенко)', 36.0)
# (None, 'Бойчука (Кіквідзе)', 50.0)
# (None, 'Тираспільська', 71.0)
# ("Солом'янський", 'Університетська', 60.51)
# ('Оболонський', 'Оболонський', 80.66)
# (None, 'Ахматової', 123.0)
# ('Подільський', 'Правди', 74.0)
# ('Дарницький', 'Зарічна', 81.0)
# (None, 'Закревського', 43.0)
# ('Дарницький', 'Бориспільська', 84.0)
# ('Шевченківський', 'Герцена', 46.0)
# ('Шевченківський', 'Герцена', 46.0)
# ('Шевченківський', 'Герцена', 46.0)
# ('Оболонський', 'Балтійський', 55.0)
# (None, 'Шаповала (Механізаторів)', 136.0)
# ('Шевченківський', 'Глибочицька', 21.31)
# ('Шевченківський', 'Салютна', 136.0)
# ('Дарницький', 'Ревуцького', 41.0)
# ('Подільський', 'Набережно-Рибальська', 71.0)
# (None, "Мар'яненко", 57.0)
# ('Шевченківський', 'Павлівська', 149.0)
# ('Печерський', 'Саперне Поле', 50.0)
# (None, 'Русовий', 75.0)
# (None, 'Драгомирова', 92.0)
# (None, 'Яблонській', 60.0)
# (None, 'Гончара', 70.99)
# ("Солом'янський", 'Університетська', 60.51)
# ('Оболонський', 'Дніпровська', 55.0)
# ('Дніпровський', 'Регенераторна', 83.0)
# ('Голосіївський', 'Деміївська', 55.0)
# ('Голосіївський', 'Деміївська', 55.0)
# ("Солом'янський", 'Новопольова', 36.0)
# ('Печерський', 'Бастіонна', 65.0)
# (None, 'Сверстюка (Марини Раскової)', 112.0)
# ('Оболонський', 'Героїв Сталінграда', 50.0)
# ('Подільський', 'Правди', 68.0)
# ('Подільський', 'Правди', 85.0)
# ('Оболонський', 'Героїв Сталінграда', 51.0)
# (None, 'Яблучна', 46.0)
# (None, 'Коновальця (Щорса)', 207.0)
# ('Оболонський', 'Героїв Сталінграда', 130.0)
# (None, 'Мирного', 81.0)
# (None, 'Заболотного', 41.0)
# (None, 'Сверстюка (Марини Раскової)', 50.0)
# ('Печерський', 'Предславинська', 54.0)
# (None, 'Заболотного', 83.0)
# (None, 'Омельяновича-Павленка (Суворова)', 81.0)
# ("Солом'янський", 'Єреванська', 44.0)
# (None, 'Чавдар', 90.0)
# (None, 'Бойчука (Кіквідзе)', 79.0)
# ('Подільський', 'Правди', 43.0)
# (None, 'Коперника', 51.0)
# (None, 'Лебедєва', 126.1)
# ('Дарницький', 'Драгоманова', 54.9)
# (None, 'Ахматової', 110.0)
# (None, 'Голосіївський (40-річчя Жовтня)', 106.0)
# (None, 'Панельна', 72.0)
# (None, 'Січових Стрільців (Артема)', 122.0)
# (None, 'Заболотного', 67.0)
# (None, 'Богомольця', 273.0)
# (None, 'Палладіна', 83.0)
# (None, 'Перемоги (Брест-Литовський)', 45.0)
# ('Оболонський', 'Богатирська', 74.6)
# (None, 'Червоноткацька', 26.9)
# ('Дарницький', 'Зарічна', 49.0)
# (None, 'Бажана', 84.1)
# ('Подільський', 'Воздвиженська', 183.0)
# ('Деснянський', 'Градинська', 48.3)
# ('Шевченківський', 'Глибочицька', 76.0)
# ('Шевченківський', 'Тургенєвська', 160.0)
# (None, 'Тираспільська', 40.82)
# ('Голосіївський', 'Ломоносова', 59.5)
# (None, 'Гречка', 73.0)
# ('Подільський', 'Правди', 46.79)
# ('Голосіївський', 'Ломоносова', 44.0)
# (None, 'Алмазова (Кутузова)', 75.0)
# (None, 'Лобановського (Червонозоряний)', 60.0)
# (None, 'Наумова', 34.0)
# ('Оболонський', 'Полярна', 65.0)
# (None, 'Українки', 190.0)
# ('Печерський', 'Дарвіна', 240.0)
# (None, 'Драгомирова', 85.0)
# ('Печерський', 'Предславинська', 48.0)
# (None, 'Липківського (Урицького)', 75.0)
# ('Голосіївський', 'Паньківська', 60.0)
# (None, 'Лаврухіна', 49.7)
# (None, 'Василенка', 47.18)
# ('Дарницький', 'Зарічна', 50.0)
# (None, 'Бендукідзе', 71.0)
# (None, 'Цісик (Гамарника)', 30.34)
# ('Дарницький', 'Урлівська', 68.0)
# ('Печерський', 'Печерський', 44.0)
# ('Печерський', 'Саперне Поле', 48.0)
# ('Деснянський', 'Крайня', 46.0)
# ('Дарницький', 'Причальна', 63.9)
# ('Голосіївський', 'Микільсько-Ботанічна', 92.48)
# ('Печерський', 'Предславинська', 63.0)
# ('Оболонський', 'Героїв Дніпра', 71.0)
# (None, 'Максимовича (Онуфрія Трутенко)', 35.0)
# ('Подільський', 'Замковецька', 48.0)
# (None, 'Симоненко', 56.0)
# (None, 'Коновальця (Щорса)', 206.0)
# (None, 'Назарівська (Вєтрова)', 172.0)
# ('Дніпровський', 'Регенераторна', 45.0)
# (None, 'Перемоги (Брест-Литовський)', 85.0)
# ('Подільський, Шевченківський', 'Стеценка', 49.0)
# ('Оболонський', 'Героїв Сталінграда', 193.0)
# (None, 'Голосіївський (40-річчя Жовтня)', 41.3)
# (None, 'Гавела (Івана Лепсе)', 43.0)
# (None, 'Б. Житомирська', 350.0)
# (None, 'І. Павла ІІ (Патріса Лумумби)', 127.0)
# ('Дніпровський', 'Регенераторна', 77.9)
# ('Голосіївський, Печерський', 'Ковпака', 180.0)
# (None, 'Бойчука (Кіквідзе)', 54.54)
# (None, 'Максимовича (Онуфрія Трутенко)', 0.0)
# (None, 'Курбаса (50-річчя Жовтня)', 60.0)
# ('Оболонський', 'Героїв Сталінграда', 60.0)
# ('Подільський, Оболонський', 'Вишгородська', 174.0)
# ('Дарницький', 'Урлівська', 73.0)
# ('Шевченківський', 'Дегтярівська', 93.0)
# ('Дніпровський, Дарницький', 'Харківське', 73.2)
# ('Дарницький', 'Урлівська', 140.0)
# (None, 'Перемоги (Брест-Литовський)', 50.0)
# ('Голосіївський', 'Ломоносова', 88.0)
# (None, 'Заболотного', 47.8)
# (None, 'Маккейна (Івана Кудрі)', 43.0)
# ('Дарницький', 'Толстого', 72.0)
# ("Солом'янський", "Солом'янська", 247.0)
# ("Солом'янський", "Солом'янська", 247.0)
# ('Оболонський', 'Героїв Сталінграда', 250.0)
# ('Дніпровський', 'Каховська', 67.0)
# ('Голосіївський', 'Теремківська', 81.0)
# ('Дніпровський', 'Микільсько-Слобідська', 33.0)
# (None, 'Тимошенко', 58.3)
# ('Дарницький', 'Зарічна', 93.0)
# (None, 'Закревського', 109.0)
# (None, 'Конєва', 70.05)
# (None, 'Туполєва', 55.0)
# (None, 'Сверстюка (Марини Раскової)', 88.0)
# (None, 'Соборності (Поєднання)', 44.2)
# (None, 'Гедройця (Тверська)', 150.0)
# (None, 'Сверстюка (Марини Раскової)', 87.0)
# ('Печерський, Голосіївський, Шевченківський', 'Жилянська', 275.0)
# ('Святошинський', 'Кольцова', 80.0)
# ('Дарницький', 'Драгоманова', 54.0)
# (None, 'Перемоги (Брест-Литовський)', 43.0)
# ('Дарницький', 'Драгоманова', 94.0)
# (None, 'Маккейна (Івана Кудрі)', 42.0)
# ('Голосіївський, Печерський ', 'Наддніпрянське', 33.8)
# ('Дарницький', 'Урлівська', 116.0)
# ("Солом'янський", 'Богданівська', 76.0)
# ('Святошинський', 'Зодчих', 59.0)
# ('Шевченківський', 'Тургенєвська', 200.0)
# ('Шевченківський', 'Герцена', 70.0)
# ('Шевченківський', 'Герцена', 70.0)
# ('Шевченківський', 'Герцена', 70.0)
# (None, 'Руденко', 75.5)
# (None, 'Грушевського', 150.0)
# (None, 'Миколи Голого (Лебедєва-Кумача)', 162.0)
# (None, 'Омельяновича-Павленка (Суворова)', 45.0)
# ('Подільський', 'Північно-Сирецька', 62.0)
# (None, 'Б. Житомирська', 75.0)
# (None, 'Українки', 90.4)
# (None, 'Тютюнника (Анрі Барбюса)', 70.0)
# (None, 'Данченко', 95.0)
# ('Голосіївський, Печерський', 'Ковпака', 555.0)
# (None, 'Радченко', 37.62)
# (None, 'Лебедєва', 93.0)
# (None, 'Драгомирова', 55.0)
# (None, 'Драгомирова', 102.0)
# ('Подільський', 'Набережно-Рибальська', 94.0)
# (None, 'Сергія Колоса (Леніна)', 41.0)
# ('Дарницький', 'Причальна', 77.5)
# (None, 'Перемоги (Брест-Литовський)', 87.98)
# ('Дніпровський', 'Визволителів', 65.91)
# (None, 'Сверстюка (Марини Раскової)', 67.0)
# ('Подільський', 'Набережно-Рибальська', 127.24)
# (None, 'Порика', 31.0)
# (None, 'Гречка', 87.0)
# ('Дарницький', 'Зарічна', 82.0)
# (None, 'Бажана', 50.0)
# (None, 'Радченко', 40.0)
# ('Шевченківський', 'Михайлівська', 70.0)
# ('Шевченківський', 'Михайлівська', 70.0)
# ('Голосіївський', 'Ломоносова', 75.0)
# (None, 'Щербаківського (Щербакова)', 96.0)
# (None, 'Симоненко', 56.0)
# ('Оболонський', 'Дніпровська', 43.0)
# (None, 'Драгомирова', 119.0)
# ('Подільський', 'Андріївська', 43.0)
# ('Подільський', 'Копилівська', 22.0)
# ('Дарницький', 'Урлівська', 105.0)
# ("Солом'янський", 'Єреванська', 44.0)
# ('Дарницький', 'Драгоманова', 69.0)
# (None, 'ЖК Stanford', 45.0)
# ('Подільський', 'Правди', 95.0)
# (None, 'Комарова', 28.0)
# ('Подільський', 'Правди', 40.0)
# ('Дарницький', 'Толстого', 161.0)
# ('Дніпровський, Дарницький', 'Харківське', 100.0)
# (None, 'ЖК Лебединий', 65.0)
# ('Шевченківський', 'Паторжинського', 213.0)
# ("Шевченківський, Солом'янський", 'Повітрофлотський', 62.0)
# ('Подільський', 'Правди', 63.0)
# (None, 'Алмазова (Кутузова)', 90.0)
# (None, 'ЖК 52 Перлина (Pechersk Plaza)', 39.0)
# (None, 'Малиновського', 73.0)
# ('Дніпровський', 'Райдужна', 34.0)
# (None, 'Маланюка (Степана Сагайдака)', 50.0)
# (None, 'Дінця', 39.0)
# (None, 'Федорова', 55.0)
# ('Дарницький', 'Срібнокільська', 58.0)
# (None, 'ЖК Nordica Residence', 52.0)
# (None, 'Липківського (Урицького)', 92.0)
# (None, 'Дінця', 68.0)
# (None, 'Маланюка (Степана Сагайдака)', 84.7)
# (None, 'Перемоги (Брест-Литовський)', 65.0)
# (None, 'Парково-Сирецька (Шамрило Тимофія)', 145.0)
# ('Голосіївський', 'Ломоносова', 58.0)
# ('Деснянський', 'Маяковського', 76.0)
# ('Шевченківський', 'Багговутівська', 46.0)
# ('Дніпровський', 'Дарницький', 88.0)
# (None, 'Чавдар', 93.3)
# ('Голосіївський, Печерський ', 'Наддніпрянське', 41.6)
# ('Оболонський', 'Героїв Сталінграда', 58.0)
# ('Подільський', 'Правди', 52.0)
# (None, 'Конєва', 70.0)
# ('Дніпровський', 'Воскресенська', 65.0)
# ('Печерський', 'Саперне Поле', 47.0)
# ('Голосіївський', 'Ясинуватський', 79.0)
# (None, 'Потапова', 34.0)
# (None, 'Кондратюка', 98.0)
# (None, 'Чаадаєва', 50.0)
# (None, 'Пчілки', 70.0)
# (None, 'Гречка', 45.0)
# ('Печерський', 'Саперне Поле', 150.0)
# ('Шевченківський', 'Глибочицька', 66.0)
# ('Дарницький', 'Причальна', 65.0)
# (None, 'Болсунівська (Сергія Струтинського)', 130.0)
# (None, 'Сікорського (Танкова)', 70.0)
# ('Голосіївський', 'Костанайська', 60.0)
# ('Оболонський', 'Богатирська', 78.0)
# ('Дарницький', 'Малоземельна', 53.0)
# ('Подільський', 'Спаська', 65.0)
# ('Святошинський', 'Прорізна', 87.3)
# ('Шевченківський', 'Прорізна', 87.3)
# ('Деснянський', 'Милославська', 69.0)
# (None, 'ЖК Бульвар Фонтанів', 61.0)
# (None, 'Драгомирова', 81.0)
# (None, 'Гавела (Івана Лепсе)', 57.0)
# (None, 'Данченко', 48.0)
# (None, 'Шолуденко', 47.0)
# ('Шевченківський', 'Михайлівський', 93.0)
# (None, 'ЖК CRYSTAL RESIDENCE', 49.0)
# (None, 'Бойчука (Кіквідзе)', 66.25)
# (None, 'Антоновича (Горького)', 72.0)
# ('Шевченківський', 'Ольжича', 65.0)
# ('Дарницький', 'Ревуцького', 49.0)
# (None, 'ЖК Берег Дніпра', 31.0)
# ("Солом'янський", 'Практична', 41.0)
# (None, 'Жмаченко', 53.0)
# (None, 'Скрипника (Микола Островського)', 77.0)
# (None, 'Коновальця (Щорса)', 100.0)
# (None, 'Бажана', 55.0)
# (None, 'Григоренко', 58.0)
# (None, 'ЖК Manhattan city', 52.0)
# (None, 'Драгомирова', 312.0)
# (None, 'Данченко', 87.0)
# (None, 'Бутишев (Андрія Іванова)', 145.0)
# (None, 'Маккейна (Івана Кудрі)', 50.0)
# ('Печерський', 'Лейпцизька', 125.0)
# ('Подільський', 'Правди', 43.0)
# (None, 'Болсунівська (Сергія Струтинського)', 130.0)
# (None, 'Драгомирова', 81.0)
# ('Печерський', 'Старонаводницька', 208.0)
# ("Солом'янський", 'Протасів Яр', 306.0)
# ('Оболонський', 'Дніпровська', 54.0)
# (None, 'Лобановського (Червонозоряний)', 105.0)
# ('Оболонський', 'Дніпровська', 69.0)
# ('Шевченківський', 'Павлівська', 66.0)
# ('Голосіївський', 'Ломоносова', 67.0)
# (None, 'Ахматової', 46.0)
# (None, 'Вернадського', 104.0)
# ('Оболонський', 'Балтійський', 55.0)
# (None, 'Липківського (Урицького)', 92.0)
# (None, 'Резницька', 86.0)
# ('Дніпровський', 'Каховська', 87.0)
# (None, 'Закревського', 43.2)
# (None, 'Сверстюка (Марини Раскової)', 86.74)
# ('Подільський', 'Правди', 90.77)
# ('Оболонський', 'Героїв Сталінграда', 48.6)
# ('Подільський', 'Правди', 86.38)
# ('Оболонський', 'Героїв Дніпра', 51.0)
# (None, 'Б. Житомирська', 250.0)
# (None, 'Корольова', 25.0)
# (None, 'Крушельницької', 42.0)
# ('Дніпровський', 'Регенераторна', 46.0)
# ('Голосіївський', 'Голосіївська', 127.0)
# ('Голосіївський', 'Голосіївська', 127.0)
# (None, 'Старокиївська', 46.0)
# ('Оболонський', 'Дніпровська', 66.0)
# ('Оболонський', 'Героїв Сталінграда', 122.8)
# (None, 'Сікорського (Танкова)', 70.0)
# ('Голосіївський, Печерський, Шевченківський', 'Саксаганського', 81.0)
# ('Дарницький', 'Драгоманова', 54.9)
# ('Оболонський', 'Героїв Дніпра', 41.3)
# (None, 'Велика Васильківська (Червоноармійська)', 85.0)
# (None, 'Малевича (Василя Боженка)', 79.0)
# ('Подільський', 'Юрківська', 83.0)
# ('Шевченківський', 'Нагірна', 38.0)
# ('Подільський', 'Щекавицька', 160.0)
# ('Подільський', 'Щекавицька', 160.0)
# (None, 'Жуковського', 37.0)
# ('Шевченківський', 'Павлівська', 198.3)
# (None, 'Маккейна (Івана Кудрі)', 108.0)
# (None, 'Бальзака', 150.0)
# ('Дарницький', 'Приозерна', 72.0)
# ('Оболонський', 'Приозерна', 72.0)
# ('Печерський', 'Інститутська', 130.9)
# ('Подільський', 'Правди', 41.0)
# (None, 'Коновальця (Щорса)', 53.0)
# ('Дарницький', 'Зарічна', 43.0)
# (None, 'Стражеска', 46.5)
# ('Дніпровський, Дарницький', 'Харківське', 71.0)
# ('Печерський, Голосіївський, Шевченківський', 'Жилянська', 56.0)
# ('Дарницький', 'Бориспільська', 118.0)
# ('Дніпровський', 'Воскресенська', 80.0)
# (None, 'Дігтярна', 85.0)
# (None, "Сім'ї Прахових (Гайдара)", 104.0)
# ('Оболонський', 'Богатирська', 60.27)
# (None, 'Мурашка', 47.3)
# ('Шевченківський', 'Щусєва', 31.0)
# ('Шевченківський', 'Щусєва', 31.0)
# (None, 'Андрющенко', 90.0)
# (None, 'Ділова (Георгія Димитрова)', 104.0)
# (None, 'Перемоги (Брест-Литовський)', 46.0)
# (None, 'Маккейна (Івана Кудрі)', 103.0)
# (None, 'Драйзера', 38.0)
# ('Дарницький', 'Срібнокільська', 111.0)
# (None, 'Туманяна', 90.0)
# (None, 'Відрадний (Чубаря)', 55.8)
# ('Оболонський', 'Попова', 79.0)
# ('Оболонський', 'Попова', 79.0)
# ('Дніпровський', 'Зелена', 74.0)
# ("Солом'янський", 'Зелена', 74.0)
# ('Шевченківський', 'Зелена', 74.0)
# (None, 'Курчатова', 46.0)
# (None, 'Архипенко (Залки Мате)', 49.0)
# ('Дарницький', 'Здолбунівська', 76.0)
# ('Деснянський', 'Градинська', 103.0)
# ('Оболонський', 'Дніпровська', 46.5)
# ('Голосіївський', 'Теремківська', 110.0)
# (None, 'Українки', 70.0)
# ("Солом'янський", 'Ушинського', 95.09)
# ("Солом'янський", 'Ушинського', 95.09)
# ('Подільський', 'Бондарський', 60.0)
# ('Деснянський', 'Милославська', 93.0)
# ('Оболонський', 'Героїв Сталінграда', 130.0)
# ("Солом'янський", 'Практична', 25.0)
# ('Шевченківський', 'Герцена', 55.0)
# ('Шевченківський', 'Герцена', 55.0)
# ('Шевченківський', 'Герцена', 55.0)
# ('Шевченківський', 'Тургенєвська', 171.0)
# ('Деснянський', 'Магнітогорська', 43.0)
# ('Оболонський', 'Героїв Сталінграда', 48.0)
# ('Шевченківський', 'Полтавська', 87.0)
# (None, 'Перемоги (Брест-Литовський)', 53.0)
# (None, 'Річкова', 84.0)
# ('Подільський', 'Ярославська', 46.0)
# ('Голосіївський', 'Деміївська', 52.0)
# ('Голосіївський', 'Деміївська', 52.0)
# ('Печерський', 'Саперне Поле', 91.0)
# ('Дніпровський', 'Каховська', 65.0)
# (None, 'Бойчука (Кіквідзе)', 82.0)
# ('Печерський, Шевченківський', 'Хрещатик', 88.0)
# (None, 'Червоноткацька', 41.0)
# (None, 'Грушевського', 150.0)
# ('Дарницький', 'Драгоманова', 73.0)
# ('Дніпровський', 'Каховська', 81.0)
# (None, 'Антоновича (Горького)', 50.0)
# (None, 'Максимовича (Онуфрія Трутенко)', 37.0)
# (None, 'Драгомирова', 60.0)
# (None, 'ЖК POLARIS Home&Plaza', 30.0)
# (None, 'Комфортна та сучасна', 63.0)
# ('Шевченківський', 'Паторжинського', 213.0)
# (None, 'Голосіївський (40-річчя Жовтня)', 73.7)
# ('Дніпровський, Дарницький', 'Харківське', 45.1)
# (None, 'Йорданська (Гавро Лайоша)', 87.0)
# (None, 'ЖК Ярославів Град', 68.0)
# (None, 'Вільямса', 103.0)
# (None, 'Жмаченко', 79.97)
# (None, 'Радченко', 91.0)
# ('Голосіївський', 'Ясинуватський', 64.0)
# (None, 'ЖК Бульвар Фонтанів', 61.0)
# ('Подільський, Оболонський', 'Вишгородська', 94.0)
# ('Подільський, Оболонський', 'Вишгородська', 111.0)
# ('Шевченківський', 'Герцена', 46.0)
# ('Шевченківський', 'Герцена', 46.0)
# ('Шевченківський', 'Герцена', 46.0)
# ('Печерський', 'Предславинська', 40.0)
# (None, 'Вербицького', 70.0)
# ('Голосіївський', 'Тарасівська', 84.0)
# (None, 'ЖК Olympic Park', 53.0)
# (None, 'Липківського (Урицького)', 80.0)
# (None, 'Кирилівська (Фрунзе)', 70.0)
# ('Святошинський', 'Маршака', 137.0)
# ('Святошинський', 'Маршака', 137.0)
# ('Святошинський', 'Берковецька', 51.0)
# ('Дарницький', 'Драгоманова', 52.0)
# (None, 'Хмельницького', 248.0)
# ('Дарницький', 'Драгоманова', 52.0)
# (None, 'Сверстюка (Марини Раскової)', 74.0)
# ('Подільський', 'Лисянська', 108.0)
# (None, 'Антоновича (Горького)', 111.1)
# (None, 'Максимовича (Онуфрія Трутенко)', 123.89)
# ('Оболонський', 'Дніпровська', 55.0)
# ('Голосіївський', 'Васильківська', 67.0)
# (None, 'Панельна', 70.0)
# (None, 'Драгомирова', 88.0)
# (None, 'Виборзька', 24.0)
# (None, 'Гулака', 42.8)
# (None, 'Маланюка (Степана Сагайдака)', 96.19)
# (None, 'Антоновича (Горького)', 46.0)
# (None, 'Болсунівська (Сергія Струтинського)', 250.0)
# ('Дніпровський', 'Каховська', 37.0)
# ('Дарницький', 'Осокорська', 51.0)
# (None, 'Липківського (Урицького)', 61.0)
# ('Дарницький', 'Срібнокільська', 110.0)
# (None, 'Гавела (Івана Лепсе)', 64.0)
# (None, 'Теліги', 32.1)
# (None, 'Ахматової', 110.0)
# (None, 'Перемоги (Брест-Литовський)', 51.0)
# ('Голосіївський, Печерський, Шевченківський', 'Саксаганського', 70.0)
# (None, 'Українки', 45.0)
# ('Деснянський', 'Радистів', 74.2)
# ('Деснянський', 'Радистів', 74.2)
# ('Деснянський', 'Радистів', 74.2)
# ('Шевченківський', 'Лисенка', 70.0)
# (None, 'Максимовича (Онуфрія Трутенко)', 41.08)
# (None, 'Перемоги (Брест-Литовський)', 80.0)
# ('Оболонський', 'Дніпровська', 40.0)
# (None, 'Коновальця (Щорса)', 54.0)
# ('Оболонський', 'Дніпровська', 98.0)
# ('Шевченківський', 'Золотоустівська', 185.0)
# ('Подільський', 'Північно-Сирецька', 48.75)
# (None, 'Дяченка', 73.0)
# (None, 'Драгомирова', 110.0)
# ('Дніпровський', 'Лобачевського', 40.0)
# ('Дніпровський', 'Лобачевського', 40.0)
# ('Дарницький', 'Толстого', 165.0)
# (None, 'Вербицького', 74.0)
# (None, 'І. Павла ІІ (Патріса Лумумби)', 57.0)
# ('Оболонський', 'Бережанська', 70.0)
# (None, 'Сверстюка (Марини Раскової)', 86.72)
# ('Оболонський', 'Героїв Сталінграда', 78.0)
# (None, 'Перемоги (Брест-Литовський)', 58.7)
# ('Святошинський', 'Львівська', 92.0)
# ('Шевченківський', 'Львівська', 92.0)
# ('Дарницький', 'Драгоманова', 54.0)
# (None, 'Перемоги (Брест-Литовський)', 85.0)
# ('Дарницький', 'Здолбунівська', 350.0)
# (None, 'Перемоги (Брест-Литовський)', 80.1)
# (None, 'Антоновича (Горького)', 170.0)
# (None, 'Українки', 48.0)
# (None, 'Наумова', 55.0)
# (None, 'Богомольця', 230.0)
# (None, 'Бойчука (Кіквідзе)', 155.72)
# (None, 'Бойчука (Кіквідзе)', 81.6)
# ('Голосіївський', 'Голосіївська', 91.2)
# ('Голосіївський', 'Голосіївська', 91.2)
# (None, 'Малевича (Василя Боженка)', 120.3)
# (None, "Сім'ї Ідзіковських (Михайло Мішина)", 29.0)
# ('Голосіївський, Шевченківський', 'Володимирська', 67.0)
# ('Оболонський', 'Балтійський', 72.0)
# ('Голосіївський', 'Феодосійська', 55.0)
# (None, 'Кібальчича', 47.24)
# ('Дарницький', 'Ревуцького', 49.31)
# ('Печерський', 'Предславинська', 62.0)
# (None, 'Коновальця (Щорса)', 130.0)
# (None, 'Антоновича (Горького)', 67.0)
# ("Солом'янський", 'Машинобудівний', 42.0)
# (None, 'Гаврилишина (Ванди Василевської)', 74.0)
# ('Дніпровський, Дарницький', 'Харківське', 88.0)
# ('Голосіївський', 'Ломоносова', 49.0)
# (None, 'Сверстюка (Марини Раскової)', 42.0)
# (None, 'Гонгадзе (Машинобудівна)', 49.0)
# ("Шевченківський, Солом'янський", 'Повітрофлотський', 55.0)
# (None, 'Маккейна (Івана Кудрі)', 42.0)
# ('Печерський', 'Старонаводницька', 142.0)
# ("Солом'янський", 'Практична', 50.0)
# ('Оболонський', 'Оболонський', 32.0)
# ('Дарницький', 'Причальна', 44.0)
# ('Голосіївський', 'Микільсько-Ботанічна', 52.0)
# (None, 'Бойчука (Кіквідзе)', 156.0)
# ('Шевченківський', 'Глибочицька', 123.0)
# (None, 'Драгомирова', 165.0)
# ('Шевченківський', 'Глибочицька', 66.0)
# (None, 'Велика Васильківська (Червоноармійська)', 82.2)
# (None, 'Тимошенко', 41.0)
# ('Дніпровський', 'Ентузіастів', 42.0)
# (None, 'Іпсілантіївський (Аїстова)', 61.0)
# (None, 'Туманяна', 80.0)
# (None, 'Драгомирова', 119.0)
# (None, 'Чорновола (Косіора)', 53.0)
# (None, 'Болсунівська (Сергія Струтинського)', 63.0)
# (None, 'Підвисоцького', 43.0)
# ('Оболонський', 'Оболонський', 86.0)
# (None, 'Драгомирова', 120.0)
# (None, 'Котельникова', 108.0)
# ("Солом'янський", 'Нижньоключова', 94.0)
# ('Оболонський', 'Дніпровська', 115.0)
# (None, 'Радченко', 36.25)
# ('Шевченківський', 'Ясногірська', 55.0)
# ('Дніпровський', 'Каховська', 62.0)
# (None, 'ЖК Washington Concept House', 53.0)
# ('Подільський', 'Дмитрівська', 48.5)
# ('Шевченківський', 'Дмитрівська', 48.5)
# (None, 'Оболонська набережна', 122.0)
# (None, 'Чорновола (Косіора)', 90.0)
# (None, 'Дружби народів', 55.0)
# ('Голосіївський', 'Метрологічна', 40.0)
# (None, 'ЖК Forward', 46.0)
# (None, 'Коновальця (Щорса)', 340.0)
# ('Голосіївський, Печерський ', 'Наддніпрянське', 41.0)
# (None, 'Микільський (Січневий)', 47.0)
# (None, 'Коласа', 55.0)
# (None, 'ЖК Dibrova Park', 79.0)
# (None, 'Вернадського', 65.0)
# (None, 'Калнишевського (Михайло Майорова)', 32.0)
# ("Шевченківський, Солом'янський", 'Повітрофлотський', 63.0)
# ('Дніпровський', 'Микільсько-Слобідська', 50.0)
# (None, 'Перемоги (Брест-Литовський)', 36.0)
# ('Дарницький', 'Березнева', 35.0)
# ('Дніпровський', 'Березнева', 35.0)
# (None, 'ЖК Krauss Gallery', 52.0)
# (None, 'Пчілки', 50.0)
# ('Оболонський', 'Героїв Сталінграда', 165.0)
# (None, 'Перемоги (Брест-Литовський)', 71.0)
# ('Голосіївський', 'Ломоносова', 110.0)
# ("Солом'янський", 'Протасів Яр', 102.0)
# ("Солом'янський", 'Нижньоключова', 80.0)
# ('Святошинський', 'Кулібіна', 60.0)
# ('Святошинський', 'Кулібіна', 60.0)
# (None, 'Пчілки', 70.0)
# (None, 'Симиренко', 80.0)
# ('Дніпровський', 'Регенераторна', 84.0)
# (None, 'Ахматової', 72.0)
# (None, 'Коновальця (Щорса)', 96.0)
# (None, 'Віфлеємська (Академіка Шліхтера)', 32.0)
# (None, 'Гмирі', 113.0)
# ('Голосіївський', 'Голосіївська', 119.0)
# ('Голосіївський', 'Голосіївська', 119.0)
# (None, 'Вернадського', 61.0)
# (None, 'Соборності (Поєднання)', 75.0)
# (None, 'Антоновича (Горького)', 54.83)
# ('Дніпровський', 'Регенераторна', 82.0)
# (None, 'Калнишевського (Михайло Майорова)', 98.0)
# ('Подільський, Шевченківський', 'Стеценка', 32.0)
# ('Святошинський', 'Кольцова', 37.0)
# (None, 'Палладіна', 96.0)
# (None, 'Тютюнника (Анрі Барбюса)', 74.0)
# ('Святошинський', 'Львівська', 54.0)
# ('Шевченківський', 'Львівська', 54.0)
# (None, "Мар'яненко", 88.0)
# ('Подільський, Оболонський', 'Вишгородська', 125.2)
# ('Оболонський', 'Дніпровська', 65.0)
# (None, 'Андріївський', 50.0)
# ('Дарницький', 'Урлівська', 100.0)
# (None, 'Гавела (Івана Лепсе)', 125.0)
# ('Оболонський', 'Балтійський', 55.0)
# ('Шевченківський', 'Багговутівська', 55.0)
# (None, 'ЖК CRYSTAL RESIDENCE', 49.0)
# ('Оболонський', 'Балтійський', 51.89)
# (None, 'Воробйова (Курська)', 55.0)
# (None, 'Гончара', 60.4)
# ('Печерський', 'Лейпцизька', 130.0)
# (None, 'Тираспільська', 40.0)
# (None, 'ЖК Diadans', 56.0)
# ('Дніпровський', 'Краківська', 75.0)
# (None, 'Сабурова', 98.0)
# ('Шевченківський', 'Глибочицька', 58.4)
# ('Оболонський', 'Героїв Сталінграда', 51.0)
# (None, 'ЖК Chalet', 32.0)
# (None, 'Івана Мазепи (Січневого повстання)', 308.0)
# (None, 'Радченко', 30.0)
# (None, 'Алмазова (Кутузова)', 90.0)
# (None, 'Городецького', 61.0)
# (None, 'Маланюка (Степана Сагайдака)', 105.0)
# ('Дніпровський', 'Каховська', 32.0)
# (None, 'ЖК Svitlo Park', 27.0)
# ('Дарницький', 'Вишняківська', 37.0)
# ('Деснянський, Дніпровський', 'Миропільська', 76.0)
# ('Голосіївський', 'Феодосійська', 75.0)
# (None, 'Малевича (Василя Боженка)', 65.0)
# (None, 'Тютюнника (Анрі Барбюса)', 114.0)
# (None, 'Коновальця (Щорса)', 152.0)
# ('Оболонський', 'Дніпровська', 115.0)
# (None, 'Маланюка (Степана Сагайдака)', 89.0)
# ('Печерський, Голосіївський, Шевченківський', 'Жилянська', 70.0)
# ('Оболонський', 'Оболонський', 84.2)
# ('Шевченківський', 'Павлівська', 157.6)
# ('Печерський', 'Крутий', 85.0)
# ('Святошинський', 'Берковецька', 83.0)
# (None, 'Оболонська набережна', 119.0)
# ('Дарницький', 'Зарічна', 100.0)
# ('Святошинський', 'Юнацька', 42.0)
# ("Солом'янський", 'Юнацька', 42.0)
# ('Подільський', 'Правди', 44.0)
# (None, 'Драгомирова', 262.0)
# (None, 'Драгомирова', 125.0)
# ('Деснянський', 'Крайня', 35.0)
# ('Дніпровський, Дарницький', 'Харківське', 51.0)
# ('Подільський', 'Правди', 66.0)
# (None, 'Перемоги (Брест-Литовський)', 68.0)
# ('Деснянський, Дніпровський', 'Братиславська', 70.0)
# (None, 'Краснопільська', 113.0)
# (None, 'Гавела (Івана Лепсе)', 66.2)
# (None, 'Тютюнника (Анрі Барбюса)', 108.0)
# ('Подільський', 'Північно-Сирецька', 46.0)
# ('Солом’янський', 'Гарматна', 60.0)
# (None, 'Гавела (Івана Лепсе)', 125.0)
# ('Оболонський', 'Героїв Сталінграда', 58.0)
# (None, 'Бойчука (Кіквідзе)', 198.5)
# (None, 'Кривоноса', 120.0)
# (None, 'ЖК Ярославів Град', 68.0)
# ('Дарницький', 'Бориспільська', 42.0)
# ('Дарницький', 'Ревуцького', 69.0)
# (None, 'Маккейна (Івана Кудрі)', 86.0)
# (None, 'Радченко', 32.0)
# (None, 'Чаадаєва', 144.3)
# (None, 'ЖК Manhattan city', 52.0)
# (None, 'Липківського (Урицького)', 92.0)
# ('Святошинський', 'Клавдіївська', 60.0)
# (None, 'Заболотного', 81.09)
# ('Голосіївський', 'Ломоносова', 189.0)
# (None, 'ЖК Володимирський', 59.0)
# ('Оболонський', 'Дніпровська', 69.0)
# ('Дарницький', 'Поліська', 48.0)
# ("Солом'янський", 'Іскрівська', 62.0)
# ('Шевченківський', 'Ризька', 87.0)
# ('Подільський', 'Правди', 83.0)
# (None, 'Антоновича (Горького)', 65.0)
# (None, 'Житловий район', 37.0)
# ('Шевченківський', 'Салютна', 56.0)
# (None, 'Омельяновича-Павленка (Суворова)', 64.0)
# (None, 'Стуса', 78.0)
# (None, 'Українки', 64.0)
# ('Дарницький', 'Вишняківська', 37.0)
# (None, 'Тютюнника (Анрі Барбюса)', 117.0)
# ('Печерський', 'Виноградний', 45.0)
# (None, 'Перемоги (Брест-Литовський)', 42.0)
# ('Оболонський', 'Дніпровська', 115.0)
# (None, 'Перемоги (Брест-Литовський)', 52.1)
# (None, 'Туполєва', 76.0)
# ('Печерський', 'Старонаводницька', 115.0)
# ('Оболонський', 'Балтійський', 40.22)
# (None, 'Бойчука (Кіквідзе)', 59.62)
# ('Печерський', 'Бастіонна', 44.0)
# ('Дарницький', 'Ревуцького', 90.0)
# (None, 'Болсунівська (Сергія Струтинського)', 68.0)
# ("Шевченківський, Солом'янський", 'Повітрофлотський', 46.22)
# ('Шевченківський', 'Золотоустівська', 106.2)
# (None, 'Русовий', 85.0)
# ('Голосіївський, Печерський, Шевченківський', 'Саксаганського', 130.0)
# ('Голосіївський', 'Теремківська', 45.0)
# (None, 'Кібальчича', 46.0)
# (None, 'Радченко', 40.95)
# (None, 'Голосіївський (40-річчя Жовтня)', 112.0)
# ('Голосіївський', 'Лисогірський', 55.2)
# ('Шевченківський', 'Гоголівська', 86.2)
# (None, 'Тютюнника (Анрі Барбюса)', 55.0)
# ("Солом'янський", "Солом'янська", 41.0)
# ("Солом'янський", "Солом'янська", 41.0)
# ('Оболонський', 'Героїв Сталінграда', 75.0)
# ('Шевченківський', 'Глибочицька', 125.0)
# ('Печерський, Голосіївський, Шевченківський', 'Жилянська', 124.14)
# (None, 'Доброхотова', 78.9)
# ('Печерський, Голосіївський, Шевченківський', 'Жилянська', 158.0)
# (None, 'Відрадний (Чубаря)', 44.0)
# ('Печерський', 'Предславинська', 48.0)
# (None, 'Іпсілантіївський (Аїстова)', 61.0)
# ('Шевченківський', 'Глибочицька', 66.0)
# (None, 'Голосіївський (40-річчя Жовтня)', 133.0)
# ('Оболонський', 'Оболонський', 47.0)
# ('Шевченківський', 'Багговутівська', 135.0)
# ('Подільський', 'Правди', 35.0)
# ('Дарницький', 'Причальна', 44.0)
# (None, 'Бойчука (Кіквідзе)', 64.8)
# ('Деснянський', 'Радистів', 41.0)
# ('Деснянський', 'Радистів', 41.0)
# ('Деснянський', 'Радистів', 41.0)
# ('Шевченківський', "Лук'янівська", 51.0)
# ('Шевченківський', "Лук'янівська", 51.0)
# ('Подільський', 'Правди', 55.0)
# (None, 'Шевельова (Микола Руднєва)', 81.0)
# ('Оболонський', 'Героїв Сталінграда', 82.0)
# (None, 'Єфремова (Уборевича Командарма)', 89.0)
# ('Оболонський', 'Балтійський', 44.3)
# (None, 'Бойчука (Кіквідзе)', 44.0)
# (None, 'Івана Мазепи (Січневого повстання)', 358.0)
# (None, 'Гришко', 95.0)
# (None, "Сім'ї Сосніних", 68.0)
# ('Дніпровський, Дарницький', 'Харківське', 112.0)
# ('Деснянський', 'Будищанська', 38.0)
# (None, 'МФК Intergal City', 44.0)
# ('Печерський', 'Мечнікова', 72.4)
# ('Оболонський', 'Дніпровська', 40.0)
# ('Деснянський', 'Маяковського', 70.0)
# (None, 'Гончара', 57.51)
# (None, 'І. Павла ІІ (Патріса Лумумби)', 63.0)
# (None, 'ЖК Rusaniv Residence', 42.0)
# ('Оболонський', 'Героїв Сталінграда', 120.0)
# (None, 'Драгомирова', 120.0)
# (None, 'Драгомирова', 70.0)
# ('Оболонський', 'Героїв Сталінграда', 160.0)
# (None, 'ЖК Olympic Park', 53.0)
# (None, 'Драгомирова', 222.0)
# ('Шевченківський', 'Бессарабська', 104.0)
# ('Голосіївський', 'Ломоносова', 44.0)
# (None, 'Тираспільська', 47.0)
# (None, 'Франка', 200.3)
# ('Печерський', 'Шовковична', 72.0)
# (None, 'ЖК Берег Дніпра', 31.0)
# (None, 'Голосіївський (40-річчя Жовтня)', 66.0)
# ('Голосіївський', 'Ломоносова', 120.0)
# ('Оболонський', 'Героїв Сталінграда', 95.0)
# ('Дніпровський', 'Регенераторна', 112.0)
# ('Шевченківський', 'Салютна', 50.0)
# ('Печерський', 'Саперне Поле', 126.0)

# %% [markdown]
# #### для аналізу скористатися бібліотекою NumPy

# %%
import numpy as np

# %%
# створити np-масив з списку `result_list`
result_arr = np.array(result_list)

print(type(result_arr), result_arr.shape)

# створимо масив с результатами тестів 
test_result = np.delete(result_arr, [0,1], 1)

# Значення 'None' - не є числом, то заміним його на 0
test_result[test_result == None] = ''

print(test_result)
# Out:
# <class 'numpy.ndarray'> (837, 3)
# [[73.0]
#  [110.27]
#  [100.0]
#  [58.0]
#  [79.0]
#  [138.7]
#  [201.4]
#  [87.0]
#  [40.0]
#  [51.0]
#  [48.0]
#  [85.0]
#  [76.0]
#  [56.0]
#  [56.0]
#  [38.0]
#  [70.0]
#  [70.0]
#  [103.0]
#  [56.44]
#  [69.0]
#  [47.39]
#  [50.0]
#  [64.0]
#  [96.0]
#  [46.0]
#  [44.0]
#  [100.0]
#  [240.0]
#  [72.1]
#  [75.0]
#  [78.0]
#  [126.0]
#  [93.0]
#  [63.0]
#  [44.0]
#  [67.92]
#  [52.0]
#  [99.0]
#  [96.0]
#  [65.0]
#  [50.0]
#  [76.0]
#  [45.3]
#  [99.0]
#  [74.7]
#  [59.0]
#  [73.0]
#  [62.0]
#  [76.0]
#  [76.0]
#  [210.0]
#  [33.0]
#  [66.8]
#  [62.0]
#  [102.1]
#  [110.0]
#  [51.0]
#  [44.0]
#  [91.0]
#  [28.0]
#  [56.0]
#  [67.3]
#  [100.0]
#  [82.0]
#  [122.0]
#  [45.0]
#  [75.0]
#  [34.0]
#  [46.0]
#  [100.0]
#  [99.0]
#  [75.0]
#  [62.0]
#  [76.0]
#  [210.0]
#  [33.0]
#  [66.8]
#  [62.0]
#  [102.1]
#  [110.0]
#  [51.0]
#  [44.0]
#  [91.0]
#  [28.0]
#  [56.0]
#  [67.3]
#  [100.0]
#  [82.0]
#  [122.0]
#  [45.0]
#  [75.0]
#  [34.0]
#  [46.0]
#  [100.0]
#  [99.0]
#  [75.0]
#  [62.0]
#  [72.0]
#  [72.0]
#  [72.0]
#  [116.3]
#  [159.0]
#  [76.0]
#  [47.32]
#  [44.0]
#  [95.0]
#  [240.0]
#  [36.0]
#  [50.0]
#  [71.0]
#  [60.51]
#  [80.66]
#  [123.0]
#  [74.0]
#  [81.0]
#  [43.0]
#  [84.0]
#  [46.0]
#  [46.0]
#  [46.0]
#  [55.0]
#  [136.0]
#  [21.31]
#  [136.0]
#  [41.0]
#  [71.0]
#  [57.0]
#  [149.0]
#  [50.0]
#  [75.0]
#  [92.0]
#  [60.0]
#  [70.99]
#  [60.51]
#  [55.0]
#  [83.0]
#  [55.0]
#  [55.0]
#  [36.0]
#  [65.0]
#  [112.0]
#  [50.0]
#  [68.0]
#  [85.0]
#  [51.0]
#  [46.0]
#  [207.0]
#  [130.0]
#  [81.0]
#  [41.0]
#  [50.0]
#  [54.0]
#  [83.0]
#  [81.0]
#  [44.0]
#  [90.0]
#  [79.0]
#  [43.0]
#  [51.0]
#  [126.1]
#  [54.9]
#  [110.0]
#  [106.0]
#  [72.0]
#  [122.0]
#  [67.0]
#  [273.0]
#  [83.0]
#  [45.0]
#  [74.6]
#  [26.9]
#  [49.0]
#  [84.1]
#  [183.0]
#  [48.3]
#  [76.0]
#  [160.0]
#  [40.82]
#  [59.5]
#  [73.0]
#  [46.79]
#  [44.0]
#  [75.0]
#  [60.0]
#  [34.0]
#  [65.0]
#  [190.0]
#  [240.0]
#  [85.0]
#  [48.0]
#  [75.0]
#  [60.0]
#  [49.7]
#  [47.18]
#  [50.0]
#  [71.0]
#  [30.34]
#  [68.0]
#  [44.0]
#  [48.0]
#  [46.0]
#  [63.9]
#  [92.48]
#  [63.0]
#  [71.0]
#  [35.0]
#  [48.0]
#  [56.0]
#  [206.0]
#  [172.0]
#  [45.0]
#  [85.0]
#  [49.0]
#  [193.0]
#  [41.3]
#  [43.0]
#  [350.0]
#  [127.0]
#  [77.9]
#  [180.0]
#  [54.54]
#  [0.0]
#  [60.0]
#  [60.0]
#  [174.0]
#  [73.0]
#  [93.0]
#  [73.2]
#  [140.0]
#  [50.0]
#  [88.0]
#  [47.8]
#  [43.0]
#  [72.0]
#  [247.0]
#  [247.0]
#  [250.0]
#  [67.0]
#  [81.0]
#  [33.0]
#  [58.3]
#  [93.0]
#  [109.0]
#  [70.05]
#  [55.0]
#  [88.0]
#  [44.2]
#  [150.0]
#  [87.0]
#  [275.0]
#  [80.0]
#  [54.0]
#  [43.0]
#  [94.0]
#  [42.0]
#  [33.8]
#  [116.0]
#  [76.0]
#  [59.0]
#  [200.0]
#  [70.0]
#  [70.0]
#  [70.0]
#  [75.5]
#  [150.0]
#  [162.0]
#  [45.0]
#  [62.0]
#  [75.0]
#  [90.4]
#  [70.0]
#  [95.0]
#  [555.0]
#  [37.62]
#  [93.0]
#  [55.0]
#  [102.0]
#  [94.0]
#  [41.0]
#  [77.5]
#  [87.98]
#  [65.91]
#  [67.0]
#  [127.24]
#  [31.0]
#  [87.0]
#  [82.0]
#  [50.0]
#  [40.0]
#  [70.0]
#  [70.0]
#  [75.0]
#  [96.0]
#  [56.0]
#  [43.0]
#  [119.0]
#  [43.0]
#  [22.0]
#  [105.0]
#  [44.0]
#  [69.0]
#  [45.0]
#  [95.0]
#  [28.0]
#  [40.0]
#  [161.0]
#  [100.0]
#  [65.0]
#  [213.0]
#  [62.0]
#  [63.0]
#  [90.0]
#  [39.0]
#  [73.0]
#  [34.0]
#  [50.0]
#  [39.0]
#  [55.0]
#  [58.0]
#  [52.0]
#  [92.0]
#  [68.0]
#  [84.7]
#  [65.0]
#  [145.0]
#  [58.0]
#  [76.0]
#  [46.0]
#  [88.0]
#  [93.3]
#  [41.6]
#  [58.0]
#  [52.0]
#  [70.0]
#  [65.0]
#  [47.0]
#  [79.0]
#  [34.0]
#  [98.0]
#  [50.0]
#  [70.0]
#  [45.0]
#  [150.0]
#  [66.0]
#  [65.0]
#  [130.0]
#  [70.0]
#  [60.0]
#  [78.0]
#  [53.0]
#  [65.0]
#  [87.3]
#  [87.3]
#  [69.0]
#  [61.0]
#  [81.0]
#  [57.0]
#  [48.0]
#  [47.0]
#  [93.0]
#  [49.0]
#  [66.25]
#  [72.0]
#  [65.0]
#  [49.0]
#  [31.0]
#  [41.0]
#  [53.0]
#  [77.0]
#  [100.0]
#  [55.0]
#  [58.0]
#  [52.0]
#  [312.0]
#  [87.0]
#  [145.0]
#  [50.0]
#  [125.0]
#  [43.0]
#  [130.0]
#  [81.0]
#  [208.0]
#  [306.0]
#  [54.0]
#  [105.0]
#  [69.0]
#  [66.0]
#  [67.0]
#  [46.0]
#  [104.0]
#  [55.0]
#  [92.0]
#  [86.0]
#  [87.0]
#  [43.2]
#  [86.74]
#  [90.77]
#  [48.6]
#  [86.38]
#  [51.0]
#  [250.0]
#  [25.0]
#  [42.0]
#  [46.0]
#  [127.0]
#  [127.0]
#  [46.0]
#  [66.0]
#  [122.8]
#  [70.0]
#  [81.0]
#  [54.9]
#  [41.3]
#  [85.0]
#  [79.0]
#  [83.0]
#  [38.0]
#  [160.0]
#  [160.0]
#  [37.0]
#  [198.3]
#  [108.0]
#  [150.0]
#  [72.0]
#  [72.0]
#  [130.9]
#  [41.0]
#  [53.0]
#  [43.0]
#  [46.5]
#  [71.0]
#  [56.0]
#  [118.0]
#  [80.0]
#  [85.0]
#  [104.0]
#  [60.27]
#  [47.3]
#  [31.0]
#  [31.0]
#  [90.0]
#  [104.0]
#  [46.0]
#  [103.0]
#  [38.0]
#  [111.0]
#  [90.0]
#  [55.8]
#  [79.0]
#  [79.0]
#  [74.0]
#  [74.0]
#  [74.0]
#  [46.0]
#  [49.0]
#  [76.0]
#  [103.0]
#  [46.5]
#  [110.0]
#  [70.0]
#  [95.09]
#  [95.09]
#  [60.0]
#  [93.0]
#  [130.0]
#  [25.0]
#  [55.0]
#  [55.0]
#  [55.0]
#  [171.0]
#  [43.0]
#  [48.0]
#  [87.0]
#  [53.0]
#  [84.0]
#  [46.0]
#  [52.0]
#  [52.0]
#  [91.0]
#  [65.0]
#  [82.0]
#  [88.0]
#  [41.0]
#  [150.0]
#  [73.0]
#  [81.0]
#  [50.0]
#  [37.0]
#  [60.0]
#  [30.0]
#  [63.0]
#  [213.0]
#  [73.7]
#  [45.1]
#  [87.0]
#  [68.0]
#  [103.0]
#  [79.97]
#  [91.0]
#  [64.0]
#  [61.0]
#  [94.0]
#  [111.0]
#  [46.0]
#  [46.0]
#  [46.0]
#  [40.0]
#  [70.0]
#  [84.0]
#  [53.0]
#  [80.0]
#  [70.0]
#  [137.0]
#  [137.0]
#  [51.0]
#  [52.0]
#  [248.0]
#  [52.0]
#  [74.0]
#  [108.0]
#  [111.1]
#  [123.89]
#  [55.0]
#  [67.0]
#  [70.0]
#  [88.0]
#  [24.0]
#  [42.8]
#  [96.19]
#  [46.0]
#  [250.0]
#  [37.0]
#  [51.0]
#  [61.0]
#  [110.0]
#  [64.0]
#  [32.1]
#  [110.0]
#  [51.0]
#  [70.0]
#  [45.0]
#  [74.2]
#  [74.2]
#  [74.2]
#  [70.0]
#  [41.08]
#  [80.0]
#  [40.0]
#  [54.0]
#  [98.0]
#  [185.0]
#  [48.75]
#  [73.0]
#  [110.0]
#  [40.0]
#  [40.0]
#  [165.0]
#  [74.0]
#  [57.0]
#  [70.0]
#  [86.72]
#  [78.0]
#  [58.7]
#  [92.0]
#  [92.0]
#  [54.0]
#  [85.0]
#  [350.0]
#  [80.1]
#  [170.0]
#  [48.0]
#  [55.0]
#  [230.0]
#  [155.72]
#  [81.6]
#  [91.2]
#  [91.2]
#  [120.3]
#  [29.0]
#  [67.0]
#  [72.0]
#  [55.0]
#  [47.24]
#  [49.31]
#  [62.0]
#  [130.0]
#  [67.0]
#  [42.0]
#  [74.0]
#  [88.0]
#  [49.0]
#  [42.0]
#  [49.0]
#  [55.0]
#  [42.0]
#  [142.0]
#  [50.0]
#  [32.0]
#  [44.0]
#  [52.0]
#  [156.0]
#  [123.0]
#  [165.0]
#  [66.0]
#  [82.2]
#  [41.0]
#  [42.0]
#  [61.0]
#  [80.0]
#  [119.0]
#  [53.0]
#  [63.0]
#  [43.0]
#  [86.0]
#  [120.0]
#  [108.0]
#  [94.0]
#  [115.0]
#  [36.25]
#  [55.0]
#  [62.0]
#  [53.0]
#  [48.5]
#  [48.5]
#  [122.0]
#  [90.0]
#  [55.0]
#  [40.0]
#  [46.0]
#  [340.0]
#  [41.0]
#  [47.0]
#  [55.0]
#  [79.0]
#  [65.0]
#  [32.0]
#  [63.0]
#  [50.0]
#  [36.0]
#  [35.0]
#  [35.0]
#  [52.0]
#  [50.0]
#  [165.0]
#  [71.0]
#  [110.0]
#  [102.0]
#  [80.0]
#  [60.0]
#  [60.0]
#  [70.0]
#  [80.0]
#  [84.0]
#  [72.0]
#  [96.0]
#  [32.0]
#  [113.0]
#  [119.0]
#  [119.0]
#  [61.0]
#  [75.0]
#  [54.83]
#  [82.0]
#  [98.0]
#  [32.0]
#  [37.0]
#  [96.0]
#  [74.0]
#  [54.0]
#  [54.0]
#  [88.0]
#  [125.2]
#  [65.0]
#  [50.0]
#  [100.0]
#  [125.0]
#  [55.0]
#  [55.0]
#  [49.0]
#  [51.89]
#  [55.0]
#  [60.4]
#  [130.0]
#  [40.0]
#  [56.0]
#  [75.0]
#  [98.0]
#  [58.4]
#  [51.0]
#  [32.0]
#  [308.0]
#  [30.0]
#  [90.0]
#  [61.0]
#  [105.0]
#  [32.0]
#  [27.0]
#  [37.0]
#  [76.0]
#  [75.0]
#  [65.0]
#  [114.0]
#  [152.0]
#  [115.0]
#  [89.0]
#  [70.0]
#  [84.2]
#  [157.6]
#  [85.0]
#  [83.0]
#  [119.0]
#  [100.0]
#  [42.0]
#  [42.0]
#  [44.0]
#  [262.0]
#  [125.0]
#  [35.0]
#  [51.0]
#  [66.0]
#  [68.0]
#  [70.0]
#  [113.0]
#  [66.2]
#  [108.0]
#  [46.0]
#  [60.0]
#  [125.0]
#  [58.0]
#  [198.5]
#  [120.0]
#  [68.0]
#  [42.0]
#  [69.0]
#  [86.0]
#  [32.0]
#  [144.3]
#  [52.0]
#  [92.0]
#  [60.0]
#  [81.09]
#  [189.0]
#  [59.0]
#  [69.0]
#  [48.0]
#  [62.0]
#  [87.0]
#  [83.0]
#  [65.0]
#  [37.0]
#  [56.0]
#  [64.0]
#  [78.0]
#  [64.0]
#  [37.0]
#  [117.0]
#  [45.0]
#  [42.0]
#  [115.0]
#  [52.1]
#  [76.0]
#  [115.0]
#  [40.22]
#  [59.62]
#  [44.0]
#  [90.0]
#  [68.0]
#  [46.22]
#  [106.2]
#  [85.0]
#  [130.0]
#  [45.0]
#  [46.0]
#  [40.95]
#  [112.0]
#  [55.2]
#  [86.2]
#  [55.0]
#  [41.0]
#  [41.0]
#  [75.0]
#  [125.0]
#  [124.14]
#  [78.9]
#  [158.0]
#  [44.0]
#  [48.0]
#  [61.0]
#  [66.0]
#  [133.0]
#  [47.0]
#  [135.0]
#  [35.0]
#  [44.0]
#  [64.8]
#  [41.0]
#  [41.0]
#  [41.0]
#  [51.0]
#  [51.0]
#  [55.0]
#  [81.0]
#  [82.0]
#  [89.0]
#  [44.3]
#  [44.0]
#  [358.0]
#  [95.0]
#  [68.0]
#  [112.0]
#  [38.0]
#  [44.0]
#  [72.4]
#  [40.0]
#  [70.0]
#  [57.51]
#  [63.0]
#  [42.0]
#  [120.0]
#  [120.0]
#  [70.0]
#  [160.0]
#  [53.0]
#  [222.0]
#  [104.0]
#  [44.0]
#  [47.0]
#  [200.3]
#  [72.0]
#  [31.0]
#  [66.0]
#  [120.0]
#  [95.0]
#  [112.0]
#  [50.0]
#  [126.0]]

# %%
# побудувати словник для результатів аналізу
result_dict = {
    "кількість спостережень"   : len(test_result),
    "середнє значення"         : round(np.mean(test_result),1),
    "максимальне значення"     : np.max(test_result),
    "мінімальне значення"      : np.min(test_result[np.nonzero(test_result)]),
    "стандартне відхилення"    : round(np.std(test_result),1),
    "розмах вариації"          : np.max(test_result) - np.min(test_result[np.nonzero(test_result)])
    }

# %%
result_dict
# Out:
# {'кількість спостережень': 837,
#  'середнє значення': 80.7,
#  'максимальне значення': 555.0,
#  'мінімальне значення': 21.31,
#  'стандартне відхилення': 50.1,
#  'розмах вариації': 533.69}

# %%
# вивести шапку
print(
"""
================================================
№  :   РАЙОН        : ПОКАЗЧИК        : ЗНАЧЕННЯ     
================================================
"""      
      )

# вивести результати аналізу датасета
i = 1
for key, value in result_dict.items():
    print (f'{i:<3}   {key:<25}  {value}')
    i += 1
# Out:
# ================================================
# №  :   РАЙОН        : ПОКАЗЧИК        : ЗНАЧЕННЯ
# ================================================
#
# 1     кількість спостережень     837
# 2     середнє значення           80.7
# 3     максимальне значення       555.0
# 4     мінімальне значення        21.31
# 5     стандартне відхилення      50.1
# 6     розмах вариації            533.69
